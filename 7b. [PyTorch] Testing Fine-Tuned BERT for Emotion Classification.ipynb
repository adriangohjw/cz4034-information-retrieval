# %%
from sklearn.model_selection import train_test_split
import pandas as pd
from transformers import RobertaTokenizer
import torch
from tqdm import tqdm
torch.cuda.empty_cache()
import numpy as np
from sklearn.metrics import f1_score

from torch.utils.data import TensorDataset
from transformers import BertTokenizer

from transformers import BertForSequenceClassification
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
import time

# %%
labels_dict = {'ANGRY':0, 
          'DISGUST':1, 
          'FEAR':2, 
          'HAPPY':3, 
          'SAD':4, 
          'SURPRISE':5}

# Enter your sequence here:
sequence = [
    "I'M SO GONNA KILL YOU YOU PRICK!!!",
    "Yucks.. gross...",
    "I'm hiding at home till this is over.",
    'I LOVE DONUTS',
    "A pity... a pity.",
    "WHAT?! When did this happen!!!"    
]
df = pd.read_csv('../data/labelled.csv', encoding='ISO-8859-1')
df['label'] = df['emotion'].apply(lambda x: labels_dict[x])

# %%
texts = list(df.text)[:1000]
labels = list(df.label)[:1000]

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased',
                                          do_lower_case=True)

# %%
model = BertForSequenceClassification.from_pretrained('bert-base-uncased',
                                                      num_labels = 6,
                                                      output_attentions=False,
                                                      output_hidden_states=False)
PATH = './bert emotion/BERT_emotion_epoch_10.pt'
model.load_state_dict(torch.load(PATH, map_location=torch.device('cpu')), strict=False)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# <All keys matched successfully>

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

print(device)
# Out:
# cuda

# %%
def evaluate(valid_dataloader):
    model.eval()

    total_eval_loss = 0
    y_hat, y = [], []

    for batch in tqdm(valid_dataloader):
        batch = tuple(b.to(device) for b in batch)

        inputs = {'input_ids' : batch[0],
                'attention_mask': batch[1],
                'labels' : batch[2]
                }
        
        with torch.no_grad():
            outputs = model(**inputs)

        loss = outputs[0]
        logits = outputs[1]
        total_eval_loss += loss.item()

        logits = logits.detach().cpu().numpy()
        label_ids = inputs['labels'].cpu().numpy()
        y_hat.append(logits)
        y.append(label_ids)

    avg_eval_loss = total_eval_loss/len(valid_dataloader) 

    y_hat = np.concatenate(y_hat, axis=0)
    y = np.concatenate(y, axis=0)
            
    return avg_eval_loss, y_hat, y

# %%
#Per Class Accuracy
def acpc(preds, labels):
    code_dict = {val:key for key,val in labels_dict.items()}

    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()

    for idx in np.unique(labels_flat):
        y_hat = preds_flat[labels_flat==idx]
        y = labels_flat[labels_flat==idx]
        print(f'Class: {code_dict[idx]}')
        print(f'Accuracy: {len(y_hat[y_hat==idx])/ len(y)}\n')

# %%
valid_encode = tokenizer.batch_encode_plus(
    texts,
    pad_to_max_length=True,
#     return_attention_masks=True,
    truncation=True,
    add_special_tokens=True,
    max_length=256,   
    return_tensors='pt'
)
valid_input = valid_encode['input_ids']
valid_attention = valid_encode['attention_mask']
valid_labels = torch.tensor(labels)

valid_data = TensorDataset(valid_input,
                          valid_attention,
                          valid_labels)

valid_dataloader = DataLoader(valid_data,
                              sampler = SequentialSampler(valid_data),
                              batch_size = 8)
# Out:
# C:\Users\lowbe\Anaconda3\envs\IR\lib\site-packages\transformers-4.3.3-py3.8.egg\transformers\tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).

# %%
start = time.time()
_, predictions, actual = evaluate(valid_dataloader)
print(acpc(predictions, actual))
labs = {v:k for k,v in labels_dict.items()}
for i in tqdm(range(len(predictions))):
    print(labs[np.argmax(predictions[i])], texts[i])
    print()
    
print(time.time() - start)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 125/125 [00:23<00:00,  5.38it/s]
#  39%|██████████████████████████████                                               | 390/1000 [00:00<00:00, 3799.77it/s]
# Class: ANGRY
# Accuracy: 0.3325526932084309
#
# Class: DISGUST
# Accuracy: 0.45794392523364486
#
# Class: FEAR
# Accuracy: 0.6285714285714286
#
# Class: HAPPY
# Accuracy: 0.7317073170731707
#
# Class: SAD
# Accuracy: 0.42857142857142855
#
# Class: SURPRISE
# Accuracy: 0.3951048951048951
#
# None
# DISGUST Scum of the earth.
#
# SURPRISE WOW. My  @Name Hidden  car parade must have 10,000 + in Vegas today. Miles of cars!!! Miles. Will dominate Vegas Strip for hours! Weâre ready to fight! Let the battle begin. Iâm leading in Maserati with American flag flying and my beautiful fiancÃ© Cindy driving. #MAGA
#
# SURPRISE White House: Trump Signs Memo to Block Antifa Members From Entering US
#
# FEAR Can't you just feel the sheer panic from Democrats? Tomorrow is going to be HUGE. Just watch ð
#
# ANGRY Looking at all the pictures from the people who stormed the House chamber today - looks like ANTIFA in disguise to me.
#
# HAPPY Could not be more clear
#
# HAPPY Seems like this guy needs to be found and Wadded u
#
# HAPPY Make her famous!
#
# ANGRY It is confirmed that Antifa dressed up like Trump supporters. That was Antifa that stormed the building.
#
# SAD You will regret not listening to this recording
#
# HAPPY Os brasileiros estÃ£o assim... Acorda povo...
#
# ANGRY Yes! Fuck them all!!!
#
# SAD I have no words. You just have to see it
#
# FEAR President Trump trying to keep Republic alive #save The USA
#
# SURPRISE I just tweeted out urging Trump to join Parler. On Twitter there will always be a Sword of Damocles hanging over his head. Trump can really help build a social media alternative to Twitter, just by signing up and posting here as well as there <a href="/profile/DanScavino45/posts" class="at">@DanScavino45</a
#
# ANGRY Echo If you support Trump's decision to cut all US foreign aid to the Palestinians.
#
# HAPPY This is a great state. My family has been here for generations. ï¿¼ï¿¼I am not leaving. I am staying. I am fighting. I was here first. ï¿¼ï¿¼ï¿¼ï¿¼
#
# ANGRY Donât fucking leave.
#
# SURPRISE IN ONE CLICK -- You Can Contact VP Pence, Senators, Representatives and All Swing State Legislatures and Demand State Legislatures Award EC Votes to President Trump - CLICK THIS LINK NOW
#
# FEAR Either protests are marvelous demonstrations of moral conviction or they are not. Either we indulge them as part of popular participation in the democratic process or we donât. We cannot demand that one side lawfully abstain while we encourage the other to go right on ahead
#
# ANGRY TONIGHT in DC.:( Violence against patriots has begun. Please God protect them all as they STAND FOR AMERICA.#SayIt
#
# ANGRY OMG they just had a MASSIVE BLUE DUMP that put Warnock in the lead and Perdue barely ahead.New day, same old sh*t.Perdue was up by 120,000 votes. GONE!
#
# ANGRY America, home of the brave. America, home of the strong!We have just begun to fight. You want to push us? Dems are doomed!#freedom #Americabecausefuckyou #warriors #fight #doSomething #NOFEAR #win
#
# FEAR Will Twitter flag the Washington Post for misinformation for reporting that Jacob Blake was unarmed?
#
# FEAR Please read the message below carefully. We have ONE President at a time. Our President is Donald J. Trump.When President Trump speaks, listen carefully.
#
# SAD Nurse in 'perfect health' found dead after getting a COVID-19 vaccine
#
# FEAR Real eyes, realize, real lies #1984 #dopeopleknowhistory #historyrepeatsitself #totalitarianism #tyranny #bigbrother #readahistorybook
#
# FEAR What the left in both parties doesn't understand is those that are storming the White House right now are WILLING to die on their feet because they REFUSE to live on their knees.
#
# SURPRISE Parler having posting issues. Here is the BOA CEO statement on what happened at the Capitol today.
#
# ANGRY Look at this!!! Keep fighting patriots!!!
#
# ANGRY This wasn't going to happen like everyone thought it was going to happen so strap in.Take a listen...ð
#
# FEAR My Parler is being blocked. Anyone else??
#
# ANGRY Shoot all COMMIE cockroahes whether they are wearing a badge or not.
#
# FEAR While I realize that no one expected or wanted this to happen... It seems, after all, we are living in a time of testing the very fabric and strength of our Constitution and itâs Republic so correct me if Iâm wrong but doesnât the Capitol building both theoretically and actually belong to the people? Government by the people and for the people. Not people by the government and for the government. Thoughts?
#
# FEAR Everyone Please stop following this nutjob...spewing falsehoods.The Left has faked an election, the right are to cowardly to object. Leave the Republican party and join the Patriot Movement. Demand local and state Politicians adhere to our constitutional values your morals at the lowest levels of Government and start taking back our country. Begin by Having your income taxes withheld at the lowest levels (ask me why) and make everything harder for this new regime by creating the same #woke attitudes weâve seen all summer. Donât blindly follow guidelines, open your businesses, disobey BS âhealthâ orders. Make local coalitionâs, Sue / Counter Sue local officials, and state officials every turn you get. Taking America backs starts with each of us which requires we play by new rules. Please obey Law Enforcement and lawful orders which means donât commit crimes. You can do this without crime and violence. 99% of cops are on the Patriot Side.-Pissed Off Patriot
#
# SURPRISE Look What We Found: Story About Toddler Kamala Wanting âFweedomâ Plagiarized From 1965 MLK Jr. Interview
#
# ANGRY a href="/profile/stillgray/posts" class="at">@stillgray</a> | Georgia and Kansas capitol buildings have been stormed by protesters.
#
# FEAR Ashli Babbitt.14 year veteranPatriotKilled at the Capitol today.
#
# ANGRY Trump is my president for 4 more years! I will not concede or comply! I stand with patriots! Everyone else can piss off. Signed sincerely pissed off Patriot. Ps gop and dnc you are done.
#
# DISGUST It never mattered how many votes Republicans got, fix was always in, ballots always waiting in suitcases under table. Stacey Abrams is greatest fraud in US history. She makes Bernie Madoff look small time. Insanity is doing the same things over & over, expecting different result!
#
# FEAR Repost.Communist Hammer and Sickle would NEVER be on a patriot's hand. I am hearing that the viking man has been at Trump rallies recently. I stand by my:THIS IS THE 2021 ANTIFA CALENDAR: when they attempt to look manly like MAGA.
#
# DISGUST Even Jesus won't forgive you for what you've done you soulless pussy!!!!
#
# ANGRY No peace
#
# SAD Yes F you it is what you sad to do your self stand up and do not let them get away with letting communist stealing our country
#
# HAPPY ðð#ashlibabbit #ripashlibabbit
#
# ANGRY I am the one
#
# FEAR Absolutely in my gut believe that Viking man was a Trump rally infiltrator. It makes total sense. But, at this point, what the heck do I know that except this:IF IT IS CONFUSING, THAT WILY DEVIL IS AT IT AGAIN. #SayIt
#
# FEAR Does anyone truly believe that an anti-military, anti-police, Fidel Castro-inviting, Reverend Wright-loving Marxist embroiled in a child abuse scandal won fairly in the state of Georgia?I DONâTâ¼ï¸
#
# HAPPY I will laugh and laugh and laugh as the Republican Party burns to the ground in the righteous fires of holy justice
#
# SURPRISE The Georgia âRepublicanâ Secretary of State... ð¤¨ Caved to Stacey Abrams and eliminated meaningful signature matchð¤¨ Taped and leaked a phone call with the President of the United Statesð¤¨ Consistently is a source for CNN while receiving lavishing on-air praisePROBLEMâ¼ï¸
#
# DISGUST Another Traitor
#
# FEAR âHow long, O Lord? How long will the wicked be allowed to gloat?Can unjust leaders claim that God is on their sideâ leaders whose decrees permit injustice? They gang up against the righteous and condemn the innocent to death. But the Lord is my fortress; my God is the mighty rock where I hide. God will turn the sins of evil people back on them. He will destroy them for their sins. The Lord our God will destroy them.ââ­â­Psalmsâ¬ â­94
#
# ANGRY I'm pulling my white privilege card and going to demand fair elections!#StopTheSteal
#
# SURPRISE Discernment.
#
# FEAR The Trump Presidency started and ended with lies about crowd size.
#
# FEAR Please read the message below carefully. We have ONE President at a time. Our President is Donald J. Trump.When President Trump speaks, listen carefully.
#
# DISGUST I am watching the orchestrated fall of the United States of America. The leftist-hired Antifa thugs rioting in MAGA CLOTHING, then Biden finally comes out of the basement just a short time later to condemn peace-loving Patriots. It is disgusting. And all these trolls all over Parler spewing hatred, who have no idea how much worse their lives will be under communism - if they are allowed to live at all. We are Venezuela. RIP USA. ð¢
#
# ANGRY And Joe Biden won the election!! BULL SHIT!!! Trump 2020!!!!
#
# SAD I have been suspended from Twitter for 12 hours. Please let my Twitter Followers know that I am fine.The bad actors may be after the President & his supporters. So be wise, have discernment, & be careful.Pray for our country. ðâ¤ï¸ðºð¸
#
# HAPPY We the people
#
# HAPPY Just a reminder that Democrats didnât bat an eye at this and called it âmostly peacefulâ
#
# SURPRISE GOP state senators in Pennsylvania prevent swearing in of Democrat incumbent | Just The News
#
# ANGRY Meanwhile at the Biden rally....ð
#
# DISGUST These are the lab rats don't y'all get it!
#
# ANGRY WATCH: Romney Boards Flight to DC FILLED With Patriots Who Chanted 'Traitor' and Grilled Him About Ties to Biden
#
# HAPPY Let's take a short walk down memory lane, shall we?
#
# HAPPY Getting my popcorn!
#
# ANGRY Just a reminder that Mitt Romney marched with BLM before they rioted and never denounced them...
#
# FEAR To those who don't know who Alex of the Jungle Jones is go to Google and look up Bohemian Grove and click on images. Alex and his crew took these pictures of their sick satanic sacrifices. He uncovered their dark demonic secret society. He's an investigative journalist, a patriot and friend of Trump. He's not Antifa.Just one of his photos.
#
# HAPPY I just joined Parler! Looking forward to meeting everyone here.
#
# ANGRY We are taking our Country back TODAYâ¼ï¸ðºð¸ð
#
# FEAR This is no patriot - guaranteed. You can see where they valiantly attempted to look older and more manly. It didn't work. They still look like soyboy domestic terrorists paid for by the great reset elite.#SayIt
#
# ANGRY Not Trump supporters!
#
# ANGRY MIKE PENCE DEFERS TO CONGRESS!!!HE WONT USE HIS PLENARY POWERS.CUCKED!!!Swipe picture left
#
# SURPRISE So Stacey Abrams is the actual governor of Georgia. That's her identity. Abramsâ sister, meanwhile, is called Leslie Abrams Gardner. Sheâs an actual federal judge, appointed by Obama. As luck would have it, Judge Gardner is now overseeing a case on election integrity that involves a group funded by -- weâre not making this up -- Stacey Abrams, the celebrated novelist/runway model/governor. Gardner has refused to recuse herself from the case. Here's how she explained her decision.
#
# HAPPY You are a total patriot and are very smart
#
# DISGUST THE DEEP STATE HAS TAKEN OVER AMERICASCOTUSREPUBLICANSREPUBLICAN LEADERFBICIADOJNOW THE VICE PRESIDENT ALL HAVE BETRAYED WE THE PEOPLE!!
#
# FEAR ** #stopthesteal#fightback #kraken#WhiteHouse #Therealdonaldtrump#MichaelPence#realDonaldTrump#katrina#NRA #NRAILA #GunOwners #transparency2020#Walkaway#OANNetworkParler#MAGA#act #DemocratsAreCorrupt #joebidenconcede#prosecutedeepstate#EndTheDemocratcommunistParty#WhiteHouse #Dbongino <a href="/profile/OANN/posts" class="at">@OANN</a>#OANN#bansharialaw#NRA#Trump2020#KAG2020 #deepstatedestruction#newdayrevellation#americasaved
#
# ANGRY WATCH LIVE: Trump Supporters Have Torn Down Capitol Barriers â Clashing With Police
#
# FEAR Here is the question we need to ask ourselves What secret or secrets are so bad so detrimental to our country that you would do anything to hide itCorona virus. Fix an election get Trump out of office to keep the truth hidden Why did Obama not want Biden to run for officeSuppression lies hypocrisy deceit The biggest fraud and cover up in history Socialist agenda
#
# FEAR Enrique Tarrio is released without bond & the judge ordered him to stay away from Washington DC because of his claim âIâll do it againâ in regards to burning the banner. His court date is June 8th. <a href="/profile/NobleLead/posts" class="at">@NobleLead</a
#
# SURPRISE Okay...serious question...does anyone have any other solution than taking power away from the Federal government via a Convention of States under Article V of the Constitution? If you havenât considered it before...now is the time. Mark Levin, Pete Hegseth and Ben Shapiro (and many millions of others) support it. How about you? Www.conventionofstates.com
#
# ANGRY Patriots in DC are ready for tomorrow.
#
# FEAR My advice to  @Name Hidden  Tomorrow in front of Congress VP Pence should stop counting electoral votes halfway through & send everyone home. Tell them pipe burst. Next morning he can let them know he resumed counting after they left & President Trump won. Donât like it? F U.
#
# FEAR I posted this reality 11 minutes ago and not 1 echo.. Pull your head out of the sand people..
#
# ANGRY Echo until she is removed!!
#
# DISGUST Stagedâ¼ï¸I am getting sick to my somach
#
# DISGUST Either the corrupt dc cops or antifa, shot a woman at close range inside the capitol !! These commies need execution !! Corrupt, just like the politicians...
#
# FEAR All I know is the anger monster crowd starting to become overwhelming.We see what's happening in Georgia.We know what they did to our president.And I don't think we're all going to stand here peaceful for very much longer.
#
# FEAR Patriot Brothers and Sisters making the trip to DC be careful and aware out there! You will be among friends but the DC creatures don't want you there! Just be aware! Trump 2020
#
# HAPPY Love you Rush! â¤ï¸ â¤ï¸ â¤ï¸ ð
#
# SURPRISE Awesome Thank you
#
# ANGRY Never enough ammo. But choose wisely. Expend the ordinance and defeat the enemy.
#
# DISGUST Piece of shit~ sickening
#
# HAPPY I just joined Parler! Looking forward to meeting everyone here.
#
# SURPRISE So you know... Iâm at the Stare Department. Showed the model to the right people. They get it, and then this was shared with me there... this is 100% true. Share..
#
# FEAR Hope the body count on both sides is extremely fucking high! Will help cull you assholes from society!
#
# HAPPY ðºð¸ðºð¸ðºð¸ðºð¸ðºð¸ðºð¸ðºð¸ðºð¸ðºð¸ðºð¸ðºð¸ðºð¸
#
# DISGUST Over and over again, the justice system fails Black Americans when it comes to excessive force by police officers around the nation. This is Trumpâs America.
#
# SURPRISE #warroompandemic Recognize him?IMG_6098.jpeg
#
# FEAR Hey terrorist mob- Noticed a good share of you are college age. Practically freshmen. I predict your lives will be very bad from here on out, as former felons.
#
# ANGRY ECHO If you stand with President Trump till the end!
#
# SAD She passed.... May prayers go out to her family. Here are the shooters
#
# FEAR a href="/profile/linwood/posts" class="at">@linwood</a> was right - he warned about Pence being a traitor! And he is!
#
# SURPRISE So you know... Iâm at the Stare Department. Showed the model to the right people. They get it, and then this was shared with me there... this is 100% true. Share..
#
# SURPRISE "Facial recognition firm claims Antifa infiltrated Trump protesters who stormed Capitol"
#
# FEAR Trolling level: Ninja.
#
# SURPRISE BIG NEWS IN PENNSYLVANIA!
#
# ANGRY TRUMP: âIâm Asking Everyone at the US Capitol to Remain Peaceful,â Must âRespect Law Enforcementâ
#
# FEAR Democrats have Perfected the Cheat. Just look at it
#
# ANGRY Looks like the military is the only way
#
# DISGUST "We were leading, then... late in the evening and early in the morning... Boom! These explosions of Bullshit!!!" President Trum
#
# SURPRISE PERDUE LOSES 5000 VOTES IN REAL TIME
#
# ANGRY '*' YOU MIGHT HAVE MISSED: '*'GOP Senator Says Antifa Attacked His Home, Threatened His Wife And Baby
#
# DISGUST Dan Bongino exposes the mainstream media's blatant hypocrisy:"We have roundly condemned the violence tonight on this network. Everyone. Period. That's it. Where was the media when my Secret Service friends were calling me with a mob outside of the WH during the summer of protest? ... Where were the mass condemnations there?"
#
# DISGUST Harris may be a plagiarizer but so was MLK. His doctoral thesis was stolen from others. And he took chunks from others' speeches. So, I guess Harris was following in King's footsteps. Biden's a known plagiarist too. But what does it matter in the US that no longer has any use for truth or principles. US has become a nation where liars call other liars 'liars'.
#
# SURPRISE Congressman Johnson objects to the electoral college submission of Arizona
#
# SURPRISE SKETCHY: CNN and ABC News Remove 5,000 Perdue Votes During Live Broadcasts (VIDEOS)
#
# FEAR For two months, Lin Wood and Sidney Powell were saying "why bother" They're going to do another steal on January 5 anyway"They were right. And everyone in the establishment GOP who laughed at the idea of voter fraud is looking even sillier tonight.I always thought there were limits to the GOP;s naivete. I was wrong
#
# SURPRISE Newsmax calls the winner of the Loeffler race? Theyâre just like fox!
#
# DISGUST Just like the manipulated votes in the Nov election (and probably b4 that).DemocRATs are traitors and criminals .... they just can't help themselves. They can't win honestly, so CHEATERS CHEAT and steal elections.
#
# DISGUST Patriots don't dress like that
#
# ANGRY Third verse. Same as the firs!
#
# SURPRISE WATCH: Sean Hannity condemns attacks on the U.S. Capitol, urges Trump supporters to join him
#
# SURPRISE He was NOT expecting that ðð
#
# HAPPY Wipe those smiles off those facesð¡ð¡ð¡ð¡
#
# HAPPY 100% !!!1
#
# FEAR More on CIA / Italy election theft
#
# ANGRY Yep.#traitor
#
# SAD NOICE WORK! I feel like my Frens and I broke Parler today. I see where one of the videos I posted is at 1.2M views. When God divinely intervenes & this page posts a video of Trump staying in office, the goal will be 100M views. ðð»I know this has been a stressful past year, horrible few months, and sad day BUT GOD .. He isnât finished yet. Night Frens.#SayIt EllieB
#
# ANGRY #crosstherubicon #trum
#
# FEAR This is how the Iranian terrorist regime poisons the minds of the younger generation to hate Israel and the United States.This is what the media will not show you about the Iranian terrorist regime - please echo!
#
# SAD I NEVER THOUGHT Iâd live to see this Country DESTROYED! It just happened!!
#
# FEAR Mike Pence is a TRAITOR & must be charged with TREASON this morning.We The People demand it TODAY.
#
# ANGRY Thousands already on the streets of Washington D.C. ahead of tomorrow's March for Trump.
#
# SURPRISE Epic interview happening...
#
# SURPRISE 1% reporting in Georgia. Has Fox News called the race yet?
#
# DISGUST Repost
#
# FEAR Holy holy holy Lord. God of power and might. Heaven and earth are full of your glory. Hosanna is the highest. Almighty Father, oh Ancient of Days, hear the plea of your servant and those who call upon you. Part the sea of corruption. Tear down the walls of treason. Piece asunder those who mock you. Stand for our defense and we cannot do anything apart from you but with you can do all things. Move Almighty Father as the world watches to see if you are gonna move to defeat all that evil. Thank you for hearing my prayer Lord. Make those who have no backbone be filled with courage. We praise thee and love thee. Father we need thee. Amen
#
# FEAR SCARY.The level of sustained and precise balance they exhibit is completely unnerving. I found it was really kind of them allow sheep to understand that there is no way they could be used against us because they're dancing.There is literally no way a dancing robot could be used to precisely target living, breathing beings, right?
#
# FEAR If they want to prosecute those who stormed the Capitol they can start with John Sullivan of Utah, BLM activist...
#
# FEAR Indisputable photographic evidence that antifa violently broke into Congress today to inflict harm & do damage. NOT  @Name Hidden  supporters. Do not be fooled. Trump supporters are peaceful. It was antifa that created the violence in our cities over the past several months.
#
# DISGUST SHREDDED BALLOTS FOUND IN GA ALREADY! Gen FLYNN
#
# FEAR Iâm getting word from boots on the ground in DC that ANTIFA/BLM busses are getting police escorts into DC, and MAGA busses are getting pulled over and searched. In case anyone had any doubts, anyone going to DC to support your duly elected President...you are definitely on hostile ground. Stay in groups, keep your head on a swivel, and show these crony communists that America has no intention of letting these fraudulent media reported election results stand!! ðºð¸RECORD EVERYTHING!!! LOTS OF VIDEO AND PICTURES!!!#standupforamerica #dc #marchfortrump #werenotgonnatakeit
#
# DISGUST Itâs Wednesday, January 6th 2021, and the Obama/Biden administration was the most corrupt in US history.#Obamagate
#
# DISGUST Hey President Trump, My father <a href="/profile/GenFlynn/posts" class="at">@GenFlynn</a> stuck his neck out for u multiple times Couldâve been vindictiveBut knew the coup against u from day 1 wasnât ur fault and outta ur controlU still have optionsBut if u care abt ur legacy in the SLIGHTEST, youll dig deep n FIGHT!
#
# ANGRY Ah yeah its time enough of their bs
#
# DISGUST The American people have been cheated and robbed out of an election under fraudulent pretenses.We will have to fight to gain the return of that which was stolen.Our country, our constitutional rights, our freedoms, and our liberties.
#
# DISGUST The democrats didn't deserve him
#
# FEAR Ashli Babbitt.14 year veteranPatriotKilled at the Capitol today.
#
# FEAR The truth is that the whole entire government is against the people EXCEPT the President... I was just watching how the police are chasing the patriots out of DC, like dogs, just now on NTD.This is how a communist country is born. And with so many guns in the hands of the people we don't even have the courage to go and fight.. So, yes, I don't have much hopes for us.
#
# FEAR I donât give two ð©ð© what the media says . This is what happens when you expose the entire government as a corrupt criminal organization. Shut the government down !
#
# ANGRY "BULLSHIT!" Crowd Goes WILD As President Trump Slams Voter Fraud
#
# DISGUST ABHORRENT DISTORTION of todayâs events provided by cnn, msnbc, and even Chris Wallace of fox news, says Chris Salcedo of Newsmax. Perfect description, folks. Way over-hyped by the Left Propaganda Media (LPM) all afternoon.
#
# FEAR Echo if you will stand by President Trump until the very end! And follow <a href="/profile/WeloveDonaldTrumpusa/posts" class="at"><a href="/profile/WeloveDonaldTrumpusa/posts" class="at">@WeloveDonaldTrumpusa</a></a
#
# SAD WE KNEW THAT.But thanks.We also know our country is at war.#Antifa#saveamerica
#
# FEAR GEORGIAð¨They still haven't explained negative votes because the explanation is fraud. 32,400 votes taken from David Perdue live. 774,723 - 742,323 = 32,400ð»
#
# HAPPY I just joined Parler! Looking forward to meeting everyone here.
#
# HAPPY Letâs follow each other!
#
# FEAR [ð´LIVE: #HouseDebate on #ElectoralChallenge] #Washington #DC #Jan6 #Jan6th #Jan6March #GodBlessAmericaâ¤ï¸ #USAvsCCP #StopTheStealâ¼ï¸#AmericansHaveHadEnoughâ¼ï¸#DrainTheSwamp_TheDeepStateâ¼ï¸#EverythingHasJustBegunâ¼ï¸#TheGreatResetâ¼ï¸#CCPsAmbitiousMilitaryPlan#CCPVirus_TheCCPBiologicalWeapons#CCPsDaysAreNumberedâ¼ï¸#å¤©ä½å·æ® #TRUMP #Revelation #å±¬éç­æ° #Armageddon #TrumpOfGod #WW3 #FREEDOM #StealthWar #TrojanHorse #USElectionFraud #DeepState #Traitors #JoeBidenMadeInChinað¨ð³ #FYIðChina has a complete â#BGYâ plan to control the world. âBGYâ stands for, âThe plan (which) includes Blue (control the Internet), Gold (buy influence with money), and Yellow (seduce key people with sex). China also has a second plan called â3Fâ and both plans are to ruin the U.S. and to assure that China controls the world. (#MilesGuo 2017)ð#TakeDownTheCCPâ¼ï¸#CCPsPlanForGlobalDomination
#
# DISGUST Hang this bitch
#
# FEAR Biden Campaign Manager called us âF***ersâ !!!She can try to walk back, but this says volumes about her boss who calls for âunityâ while shouting that we are âassaulting democracy:âThey think we are deplorable, irredeemable âF***ersâ. SICKâ¼ï¸
#
# ANGRY âAnd then they ran to the mailboxâ boy that got me fired up!!!
#
# ANGRY Patriots! Move now to take back GREAT AMERICA! Lin wood is calling!
#
# SAD MAY THIS DATE BE FOREVER REMEMBERED."You all been asking where the Trumpie's are, right? .. We don't need no safe space."INTERMISSION January 6, 2021#marchfortrump#sayit#saveamerica
#
# ANGRY Bricks, Lumber and Propane Tanks Left Out on DC Streets Ahead of Wednesday's Stop the Steal Protests (VIDEO)
#
# HAPPY Letâs follow each other!
#
# HAPPY God Bless our great President!
#
# DISGUST Traitor Matt Drudge crawled out from under his rock again. (The race hasn't been called yet, and anything could happen).
#
# SURPRISE ð¨OBAMAGATE AUDIO LEAK: Barack Obama and The Ministry of Italy Altered Voting systems via Private Military Contractors and satellites in space. Obama funneled money going to Iran through or to Italy and conspired with PM Renzi to defraud the 2020 election.Tomorrow, FISAGATE Is suppose to air according to Q (as part of the 3 movie series) - coincidence that this âleakâ occured perfectly in time. There are no coincidences. Tomorrow, Trump will be tweeting about FISAGATE.
#
# FEAR The next time the election for senators come up, remember those that voted AGAINST the people of Arizona and the Republican Party!!!! Do NOT vote them back in. They care more about THEIR own positions than they care about the VOICE OF THE PEOPLE!!! VOTE THEM OUT!!!!!
#
# FEAR âLaw and orderâ is only a noble principle when it comes with the corollary âequal justice under the law.â If there is no equal justice, then law and order is simply a ruse by a certain class of people, who are above the law, to go after the people who are not in their âinâ grou
#
# DISGUST Said in laymenâs terms: Masks are a JOKE!
#
# ANGRY VP Pence has been rushed out. Patriots have made it to the doors of the Senate chamber.
#
# DISGUST Prepare for more fake, propaganda videos of Chinese people laying on the floor pretending to be dead in Beijing. ð¨ð³ ð¨ð³ ð¨ð³ Fool me once, shame on you. Fool me twice, shame on me. China bans corrupt WHO investigators from Wuhan, as another province goes into PRETEND âwartimeâ mode over a new outbreak.
#
# HAPPY Alle tragen neue rote Kappen. Abgetragene Kappen durch eingefleischte Trump Supporter sieht man hier kaum. Frische Ware fÃ¼r ANTIFA Soldaten.
#
# SURPRISE Statement from President DonaldTrum
#
# FEAR More Antifa causing the problems image...#wwg1wga #thestormisuponus #digitalsoldiers #fightlikeaflynn #fightback #fightfortrump #qanon #qarmy #qanons #electionfraud #trump #stopthesteal #stopthecoup #1776 #holdtheline #trump2020 #riggedelection #youmewe #wakeupamerica #trumptrain #savetherepublic #maga #veterans #kag#ElectionDeniers#marchfortrump #january6th #takebackamerica #wethepeople #american #mikepence #pence #truth #welovetrump #georgia #china #soros #constitution #saveourchildren #savethechildren #luciferians #jesus #jesuschrist #jesusislord #justiceroberts #qanonpatriots ððððºð¸ðºð¸ðºð¸
#
# SAD TRUMP in GEORGIA: âThe Most Unhappy Person Right Now Anywhere in the US is Hillary Clintonâ
#
# DISGUST Whiskey Tango Foxtrot! Another f'ing traitor!
#
# FEAR 1.6.21 POST ELECTION UPDATE #16: US Capitol Patriots Reporting From On Site. LIVESTREAM UPDATE 2PM ESTPlease Retweet...Please note: YT just hit our channel with another attack. 2nd time in YT jail (2 weeks, till Jan 20th). Untold History Channel on YT.This is the temporary backup channel for 2 weeks. Will also upload all content to Brighteon and other channels. Links can be found in Description section (Show More) under video.
#
# HAPPY Nancy Pelosi couldn't even speak over the standing ovation ð¥ð¥ð¥
#
# FEAR Note to Chief Justice John Roberts: Many are interested in docket entry numbers 41, 46, 57, 58, & 60 in Case No. 15-545 below.As head of highest court obligated to rule on election fraud cases, would you inform public of contents of these entries & then resign? Or vice versa?
#
# FEAR He can invoke all provisions of EO 13848 on Foreign Interference in this electionHe has long had all the authority he needsHe is surrounded by people who want him outThe evidence is on our sites at www.DefendingTheRepublic.orgThe media liesThe politicians are lyingThe people know the truthPOTUS can order a real investigation now. Under emergency authorities, he can stop it all but he needs to fire a lot of people now
#
# FEAR Old article.... So is he going to condemn Facebook for suspending him today? When one company bans or suspends they all do... kinda like they coordinate or talk with each other.
#
# FEAR âLaw and orderâ is only a noble principle when it comes with the corollary âequal justice under the law.â If there is no equal justice, then law and order is simply a ruse by a certain class of people, who are above the law, to go after the people who are not in their âinâ grou
#
# FEAR Seen some footage of someone on the ground inside capital hill..... not convinced they have been shot and if they had not by a police officer . Not to convinced it was real blood. . . But that'smy opinion. Will have to wait and see.
#
# HAPPY I just joined Parler! Looking forward to meeting everyone here.
#
# ANGRY ANTIFA unloaded from buses with Tags and all!!!!Completely organized!!!!! PENCE is a TRAITOR!!!
#
# FEAR JIM JORDAN Blasts Democrats: âFour years and forty million dollars on the Russian hoax, but we canât look into an election that 60 million Americans think was stolen!?â[Video]#donaldtrump #voterepublican #republicans #conservative #votetrump2020 #usnews #uspatriots #americanpatriots #maga2020 #keepamericagreat #melaniatrump #newyork #florida #arizona #illinois #nevada #california #utah #uspolitics #liberals #democrats #stopthesteal
#
# ANGRY Nancy #Pelosi and her mission to erase #Gender for 'diversity'. #US #USelection #Democrats
#
# FEAR The media is now enlarging images of protestors so they can be identified and prosecuted. Correct me if Iâm wrong, but I donât remember them doing this when Antifa and BLM were unleashing their orgy of terror and violence. Law and order demands a single standard of enforcement
#
# DISGUST Literally no one can watch this video and conclude this woman is telling the truth.This is INSANE. She's even more fake than Hillary Clinton!
#
# HAPPY AMEN!
#
# FEAR READ> RESPOND> REACT>PROTECT...... sending this ECHO from AUSTRALIA......be careful out there patriots
#
# HAPPY Agreed!!
#
# FEAR Pence Betrayed General Flynn in 2017 and Today He Betrayed President Trump and America
#
# ANGRY Must see ! Q decode for today!
#
# ANGRY This is the moment that started the clash between DC police and Trump supporters, with the DC police refusing to arrest the BLM girl who threw a punch on a Trump woman. Caught live. Share it like wildfire. This disproves everything they show on TV. Let the world see.
#
# FEAR Democrats fight dirty but we arenât afraid We wonât give up and we have God on our side ðð»ðºð¸ðð»
#
# SAD We will NOT forget these reports. Ever. ð
#
# SURPRISE Wow! WOw! WOW!!!!!!Unbelievable REAL EVIDENCE OF BIDEN CRIME FAMILY TRANSACTIONS IN UKRAINE!!!!From 3 Minutes Thru The 1 hour This IS CRAZY!! Is This The First OF MANY Massive ACTIONS TO HAPPEN THIS LAST WEEK OF 2020???Must Watch!! ECHO!!!
#
# HAPPY TRUTH.
#
# FEAR Trump Supporters did NOT STORM THE CAPITOL. Fox news...GET IT RIGHT FOR ONCE!!!Radical ð©ð©ð©heads on the left are desperate...so they stupidly throw on a red hat & carry a flag. A red hat & a flag do NOT MAKE THEM PATRIOTS. Patriots don't depend on violence to make their point. Wearing a red hat & carrying a flag is the only way these antifa cockroaches will come out in daylight. Their usual practice is....wait until dark when the numbers dwindle...then attack women & the elderly. The difference of behavior between antifa & Patriots is crystal clear. Anyone/everyone who has watched this bullð©ð©ð©ð© over past months know ANTIFA was written ALL OVER the ð©ð©ð© chaos at the Capitol today. Its a NO BRAINER!!!
#
# ANGRY WE NEED TO KILL ALL OF ANTIFA!!! THE ALL NEED TO BE DESTROYED!!!!THEY ARE TERRORISTS TO OUR COUNTRY!!!SEE WHAT THEY DID TODAY!!!THEY DESTROYED OUR COUNTRY!!!
#
# DISGUST That person is a complete pig and deserves to be found at the bottom of a river.
#
# FEAR Treason. Trials begin on the 20th.
#
# DISGUST I remember a few months ago the media promoted books in defence of looting. I guess itâs okay to steal and rob from private property but government property isnât okay. This is a double standard about who may express themselves and when itâs condoned.AOC said that protests are supposed to scare people and violence was okay.... yet these protests today, seem less violent then the ones over the summer she defended... It seems a strange double standard. Itâs wrong to shoot armed liberal protesters but itâs acceptable for police to shoot and potentially kill unarmed protesters inside the house building (which is ironically supposed to be the peopleâs building) As a country we should say all looting is wrong yet today is the first time politicians condemned it.When you censor, belittle and take away peopleâs voices and pretend you have changed minds... these are the things that happen. Disgraceful media and disgraceful leaders.
#
# HAPPY This is our call.... where we go one we go all !!!!!!
#
# SURPRISE Look at the source...
#
# FEAR Let it be known and remembered that they shot first, they took the life of an American citizen ð PARTY OF CRIME ð
#
# FEAR "they won't be able to walk down the street."-Q
#
# FEAR Please read the message below carefully. We have ONE President at a time. Our President is Donald J. Trump.When President Trump speaks, listen carefully.
#
# SURPRISE Trump rips RINO Republicans ahead of vote certification as Democrats sweep Georgia runoffs | Ep. 307 - YouTubeGET THIS ECHOED VIRALLY!!!!!!!!!!!! Make this go viral!#makethisgoviral #viral #DeclassifyEverything #WeThePeople #USA #1A #AmericaFirst #DeclareMartialLaw #MartialLaw #InsurrectionAct #FightBack #FightLikeAFlynn #DoNotConcede #HoldTheLine #StopTheSteal #Trump2020 #GodBlessAmerica #12thAmendment #Trending
#
# DISGUST States that cheat and steal elections should be stripped of electors.
#
# DISGUST This contains sensitive content which some people may find offensive or disturbing
#
# FEAR I just urged our leaders in Washington to uphold their Oaths and save our great nation. Join me by clicking this link so we can all be heard!
#
# ANGRY #Antifa Tatoos !!? â¼ï¸#lawandorder #stopthesteal
#
# FEAR The woman who was killedâwho was she? Was she a Trumpster, or Antifa posing as a Trumpster? What threat did she pose? Why was she shot and killed, and by whom? So far there seems to be very little media reporting or even curiosity about these obvious and germane questions
#
# ANGRY #French
#
# FEAR âStates want to correct their votes, which they now know were based on irregularities and fraud.â âAll Mike Pence has to do is send them back to the States, AND WE WIN. Do it Mike, this is a time for extreme courage!âPresident Donald Trump.<a href="/profile/Transparency2020/posts" class="at">@Transparency2020</a> #Transparency2020
#
# HAPPY Still with Trump ðºð¸ðºð¸ðºð¸ðºð¸âï¸âï¸ððððºð¸ð«ðâï¸ðºð¸
#
# FEAR I believe 70+ million people would echo if they were on parler.ECHO if you will never accept it!
#
# SAD âBiden Is Our President Like Maduro Is Venezuela's.â Crushing article by @DebbieDSouza in El American
#
# HAPPY Thank you <a href="/profile/Cherokeeowl/posts" class="at">@Cherokeeowl</a> and <a href="/profile/SidneyPowell/posts" class="at">@SidneyPowell</a> Truth will rise to the top and President Trump will continue to be the POTUS for the next four years.
#
# DISGUST Seeing the Congressmen and Senators cratering instantly in the face of the breach of the Capitol building tells me this was planned. These elected shills have done nothing but watch America burn from lawless Antifa and BLM. Their claims of protecting democracy by certifying a fraudulent illegal election that is a coup and communist takeover of this country is a lie
#
# DISGUST The traitors stages the whole event. They all have blood on their hands.
#
# SURPRISE WATCH This BEFORE January 6th!Rudy Giuliani HERE: youtu.be/FT_zTMdD2wM
#
# FEAR ðºð¸ð¦ Hey patriots, Sorry for the delay in updates! Still deployed. Lots of military movements happening, and there's word that NG may be deployed on the 6th in DC, we will stand behind President Trump. ð¯Also, there's an internal rumor that POTUS is going to make a BIG ANNOUNCEMENT soon. So, enjoy your New Years everyone! Make your resolutions. Remember whatever happens, Trump is our POTUS, Jesus loves you, #GODWINS, and WE will win! #godblessamerica #godblesspresidenttrump #fightback #stopthesteal #vppence #texas #stopthefraud #arizona #michigan #nevada #wisconsin #electionfraud #voterfraud #georgia #usps #fraud #fact #4moreyears #christian #riots #patriots #china #trump #trump2020 #trumpcampaign #bigtech #presidenttrump #americafirst #election2020 #maga #kag #maga2020 #supremecourt #scotus #usa #riggedelection #california #sidneypowell #Pennsylvania #stimulus #breakingnews #ccp #antifa #dominion #uspolitics #jennaellis #electionresults #holdtheline #keepthefaith #military
#
# SURPRISE Discernment.
#
# ANGRY Never Give U
#
# FEAR And JUST LIKE THAT, I have all the proof I need:IMAGE: This viking fool at a BLM protest in June. I am VERY GOOD at this Grandma-Patriot-Super-Sleuth stuff. You domestic terrorists will NOT get away with this false flag BS. #SayIt #antifa#domesticterrorism
#
# ANGRY ECHO If you stand with President Trump till the end!
#
# ANGRY Democrats Attempting To Forcibly Remove Trump From Office Over Protests
#
# DISGUST Who the hell voted for this lunatic!
#
# HAPPY TRUTH.
#
# ANGRY Pro-Trump Marine Goes Off on DC Police After They Mace Stop the Steal Protesters, 'We Had Your F***ing Back, But We Ainât Got Your Back No More!'
#
# ANGRY Just a reminder that Mitt Romney marched with BLM before they rioted and never denounced them...
#
# DISGUST Still have no fucking idea how this works
#
# SURPRISE ANTIFA/BLMWELL THIS IS INTERESTING IF TRUE.And it wouldnât surprise me at all if it was.Swipe picture left.Thanks to the person who brought this to my attention.
#
# HAPPY Stay safe. ðððððððððECHO ECHO ECHO
#
# SAD Come on man #truthisfreeð#HistoryRepeats ð¥#artimitateslifeð¥ð¦ð´I already told you Fiction Revealsð¶ TRUTH That Realityðªï¸Obscures #WWG1WGAðºð²That's what happens ð¦I'm sorryð¤#thegreatawakening#iknow #ithurts #metooð¥
#
# SURPRISE 'My Faith Votes' reaches over 1.3M Ga. voters #OANN
#
# FEAR We absolutely oppose all violence. We love and worship Jesus Christ, the Son of God.JANUARY 5, 2021 VIDEO OF COMMUNIST GEORGIA ELECTION FRAUD CENTER REFUSING TO ALLOW ANY CAMERAS OR LAWFULLY NECESSARY ELECTION WITNESSES.#pizzagate #cnn #fakenews #pedogate #jeffreyepstein #jeffzucker #donlemon #brianstelter #vanjones #obama #biden #electionfraud2020 #dominion #smartmatic #georgia #jesuitmob #chriscuomo #childtrafficking #sandyhook #falseflags #humantrafficking #communists #communism #andersoncooper #vanderbilt #franksinatra #projectmockingbird #cia #mossad #mi6 #vatican #mkultra #mindcontrol #ciantifa #cia #antifa #blm #communism #falseflags #georgiaelectionfraud #electionfraud2021 #electionfraudredo
#
# SAD We need a heart felt prayer for our nation, our President, VP, the patriots in Washingron and all those willing to stand up for this nation tomorrow and object the vote . They will go toe to toe with the devil. Please pray for them tonight and throughout the day tomorrow.
#
# SURPRISE WATCH: Fox News Reporter Escorted Out of Stop the Steal Protest By Police As Crowd Chants 'Fox News Sucks'
#
# DISGUST Hey President Trump, My father <a href="/profile/GenFlynn/posts" class="at">@GenFlynn</a> stuck his neck out for u multiple times Couldâve been vindictiveBut knew the coup against u from day 1 wasnât ur fault and outta ur controlU still have optionsBut if u care abt ur legacy in the SLIGHTEST, youll dig deep n FIGHT!
#
# HAPPY Amen sister!!!
#
# SAD THE HORRIFIC MURDER OF AN UNARMED VETERAN WOMAN. THE BLOOD IS ON CONGRESSâS HANDS!!!!
#
# SURPRISE Nebraska Governor Pete Ricketts discusses #prolife legislative accomplishments in his state in this op-ed piece. #ProLifeLawsSaveLives
#
# DISGUST Theyâve been shitting all over us and the âAmerican Spiritâ theyâve finally went to far!! Take our country back by any means. We hang together now or separately later!
#
# ANGRY Make this explosive on Parler and follow me because i will update you on everything concerning the DC marchAnonymously sent to our DM last night.@DCPoliceDept openly encouraging BLM/ANTIFA violence on #Trump supporters that have started to arrive in #WashingtonDC ahead of the #MAGA #StopTheSteaI2021 protests.
#
# DISGUST This is Germany 1938. If you donât see it, youâre either blind, deaf or really dumb. Or youâre an enemy of the greatest country (USA) & economic system (capitalism) and values (Judeo-Christian) in world history.
#
# SURPRISE Obama & Hillary Object to Certifying Electoral College Votes in 2005
#
# SAD Please pray for her family ð This is Ashli Babbitt a true patriot showing her support for  @Name Hidden  today at the #stopthesteal rally.She was killed because punk Antifa members pretending to be Trump supporters decided to break into congress smashing windows and threaten police. These are her last texts. May she Rest In Peace ð¢
#
# SURPRISE Democrat congresswoman tests positive for COVID, but she can still go to the Capitol. Meanwhile, small businesses across the country have been forced to close. Unbelievable.
#
# DISGUST EVERYONE GET UP & DANCE ððð»ðºð¸ð¯. SHITS GOING DOWN!Pepe Lives Matter on Twitter: "When you realize that nothing can stop what is coming. " / Twitter
#
# DISGUST Twitter and Facebook need to be put in prison along with the restof the treasonous people
#
# ANGRY TRUMP in DC: âWe Will Never Give Up, We Will Never Concede, Our Country Has Had Enoughâ
#
# DISGUST America is FULL OF IDIOTS Mission not accomplished, yet!
#
# FEAR Understanding that the violence in the US Capitol was wrong... how does that change why Senators and Congressmen were going to object to the results of the election?
#
# DISGUST For nearly a year, dumbo rats have been focused on ruining our country by stealing elections in the midst of a biological war waged by China. We have not held China accountable for this mess and they sit back and laugh at the destruction and misery they caused. The lack of action by Congress is nothing short of Treason. Every one of them should hang for their inaction.
#
# DISGUST The cowardly authoritarians at Twitter booted president Trump from Twitter for 12 hours. What a bunch of cowards.
#
# ANGRY Migrants chanting âBiden! Biden!â stampede border
#
# ANGRY Anqueefa used this event at their Advantage to Occupy the Capitol, the Patriots were subject to a Trojan Horse event. Now we will see the Media demonizes and further push that being a Patriot is a Threat to National Security. #capitol #January6th #RevolutionNow #trojanhorse #FF
#
# HAPPY AZ BLM rally DC Capital in Juneð todayð
#
# FEAR Things the US can look forward to in the next 6 months under Biden:ð´ 6 months of lockdowns.ð´ Collapse of gas and manufacturing industries.ð´ More censorship.ð´ Arrest and detention for âhealth threatsâ.ð´ Mass refugees.And defunding the WHO?Forget about it.One of Joe Bidenâs first executive orders will be to give it more money.Make no mistake,under Joe Biden America will be a profound socialist country.You better believe it.......
#
# FEAR Dear tone deaf Democrats, Media and Republicans, You can't antagonize over 70 million people for 4 years... then pretend they'll suddenly unite with you because of questionable results in an election... WHILE YOU'RE STILL ANTAGONIZING THEM.WAKE UP!
#
# FEAR We have taken down the fence at the Capitol !!!! Time to take america back. Keep pushing. They will not certify this STEAL!!! We will enter the building in no time if we must.
#
# SURPRISE After he lost his reelection bid in November, Donald Trump immediately told allies he planned to run for president again in 2024, preparing to announce as soon as Inauguration Day.He began backing off the idea after learning that running would require him to release a new round of financial documents that would make him vulnerable to his ongoing criminal and civil investigations and lawsuits, according to two Republicans close to Trump.
#
# ANGRY #trumpwon
#
# SURPRISE Here's the truth!ð¥ ECHO!ð Follow <a href="/profile/WeLoveTrump/posts" class="at"><a href="/profile/WeLoveTrump/posts" class="at">@WeLoveTrump</a></a> for more!
#
# ANGRY REMINDER.Insurrection Act of 1807.Proclamation to disperse before invoking the powers under the Act is a requirement. #insurrectionact#saveamerica
#
# ANGRY If youâre looking for good news then donât listen to my show today. However, if they want a fight, letâs give it to them. Listen at Bongino.com
#
# HAPPY Yup, once again all the prostitutes vote her the best madam of the best whorehouse in D.C. I bet that makes her daddy so proud of his little whore!
#
# SURPRISE Patriots catch Mitt Romney on their way to DC and â¦ UNLEASH ON HIM!BEST VIDEO OF THE DAY...
#
# ANGRY FROM POTUS.God save us.#pence#traitor
#
# FEAR Trump supporters have eradicated all barricades and are now face to face with the police, blood has been shed and many arrests are being made. Footage obtained by Julio RosasComment your thoughts down belowððBe sure to follow RPMG on Instagram: @redpillreports Parler: @theredpillmediaTwitter: @pillgrou
#
# ANGRY I'm fighting! I will never live my life as a "sheep"
#
# DISGUST Just another the slap ð to our faces! Donât forget - all this horse shit is sponsored by we the tax payers. Not only do the communists blatantly steal another election - we pay for it ð¤·ââï¸
#
# FEAR #stopthesteal, JOIN TRUMP ON JAN/6/21 IN WASHINGTON DC ! HUNDREDS OF MILLIONS PATRIOTS INCLUDED NON AMERICANS IN WESTERN COUNTRIES LIKE BRAZIL ARE SHOCKED WITH THE UNPRECEDENTED MAGNITUDE DEGREE OF CHEATING IN THE ELECTION PROMOTED BY THE CROOK, INSIDIOUS AND CRIMINAL DEMOCRAT'S NON STOP CHEATING AND WOKING MACHINE. The globalist leftists/communists thugs can't hide anymore the biggest electoral cheating ever in the political american history. Trump in USA and Bolsonaro in Brazil, just to mention 2 guardians champions of the christian/jewish cultures and values, stand beside hundreds of millions patriots who will defeat the woking globalist leftists/communists that are still populating the schools, universities, main stream medias and deep states. The ineluctable destiny of the globalist leftist/communist ideology is it erradication and destruction. #draintheswamp #electionfraud2020 #keepamericagreat #trumpwon #bidenconcede
#
# DISGUST This little maggot #antifa scum wearing his cap back to signal which side he's on, talking some BS about a shooting after breaking into our congress, throwing teargas and smearing real patriots. So transparent. (Swipe)
#
# ...
#
# SURPRISE WATCH: Eric Trump has a message for every Republican in office or thinking of running for office.
#
# SURPRISE Message left by Trump supporters in Nancy Pelosi's office in the capitol building.
#
# SURPRISE WATCH: The moment protesters stormed the Capitol buillding | Just The News
#
# SURPRISE The Georgia âRepublicanâ Secretary of State... ð¤¨ Caved to Stacey Abrams and eliminated meaningful signature matchð¤¨ Taped and leaked a phone call with the President of the United Statesð¤¨ Consistently is a source for CNN while receiving lavishing on-air praisePROBLEMâ¼ï¸
#
# DISGUST CONSERVATISM and the desire to SELF GOVERN started in Europe with the signing of the Magna Carta, brought to AMERICA, aged, tempered, and PERFECTED here while ESCAPING persecutions in Europe!What are we going to do now?WE JUST LET THESE MOTHERFUCKERS FRAUDULENTLY VOTE US OUT OF OUR OWN COUNTRY YOU IDIOTS!!!!! Conservatism is A FOREIGN concept and doesnt EXIST anywhere else in the WORLD!!!!!Conservatism DIED today!When we brought these people here from other countries, From the slimey 3rd world, SHITHOLES they where ALL living in, TO BETRAY US???THERE'S YOUR EQUALITY! FEUDALISM!There's your RACISM right there people!These people brought their feelings of hatred and betrayal into our borders!Modern liberalism TAUGHT our children not to value beliefs,but to value the corruption of the foreigners!Resistance and Retribution, is PARAMOUNT, for the survival of this NATION!IT IS TIME TO PUT DOWN THE PROTEST SIGNS AND AMERICAN FLAGS,AND PICK UP AN AR-15!
#
# SURPRISE Here We Go Again: DeKalb County Georgia is Re-Scanning Advance Ballots Because of 'Memory Card Issue'
#
# ANGRY Talks are thereâs a party in DC after dusk. Patriots vs Antifa and BLM and not where the National Guard are
#
# SURPRISE Follow <a href="/profile/buildthewall45/posts" class="at"><a href="/profile/buildthewall45/posts" class="at">@buildthewall45</a></a
#
# HAPPY AMEN ðð»
#
# HAPPY THIS IS TRUE. ð¥ ECHOð¥
#
# ANGRY BLM & Antifa burned down cities, businesses & police stations. Liberals and Democrats called that peaceful Trump Supporters aka the people went Into the peopleâs Capitol and yâall call that Violence? 25 Amendment? President Trump didnât incite Violence NOTHING IS ON FI
#
# SAD This is my son Tommy who is a proud and passionate Trump supporter. Unfortunately he gets bullied at school for this and weâve had to homeschool him as he was too anxious to go. He said to me today that he feels like heâs amongst friends on Parler. Would you please Follow us, Echo & Upvote this post to show him support? It would mean the world to him!
#
# ANGRY a href="/profile/TrumpJFKJr2Q2Q/posts" class="at">@TrumpJFKJr2Q2Q</a> COME ON NOW! PENCE GITMO BOUND AND WE THE PEOPLE ARE READY FOR YOU!
#
# SURPRISE BREAKING: Hill staffers are being told to immediately evacuate as Trump supporters are ripping down security fencing and storming the Capitol building.WATCH:
#
# FEAR Please share this photo. This women assaulted a Trump supporter busting her eye open and ran away. She was wearing an âAdmiral Security Servicesâ jacket so it seems she works for them. The closest Admiral Security places in DC are either in Bethesda, MD or Baltimore, MD
#
# FEAR Fulton County, GA. has BLOCKED The Committee to Defend the President credentialed monitors from overseeing absentee ballots and verifying signatures!They are REQUIRED to allow our observers in by the superior courtâs order.ECHO !!!
#
# SURPRISE BREAKING NOW: Ted Cruz Objects to Arizonaâs Electoral College Results, Senate to Debate
#
# HAPPY Well... well!!!#cocainemitch #kevinmccarthy
#
# FEAR The Democrats now know how to rig elections. They will win Georgia. How do I know this? The house is already working on the Green New Deal and Medicare for all, they know the outcome in Georgia! Gird your loins
#
# SURPRISE Message to all members of CongressFollow  @Name Hidden  and echo if you agree!
#
# FEAR Please share this photo. This women assaulted a Trump supporter busting her eye open and ran away. She was wearing an âAdmiral Security Servicesâ jacket so it seems she works for them. The closest Admiral Security places in DC are either in Bethesda, MD or Baltimore, MD
#
# ANGRY Fecharam, soldaram as portas dos comerciantes paulistanos, estÃ£o aumentando os impostos, ICMS, etc. Toda populaÃ§Ã£o sofrendo e este prefeito Fura Covas, aparece agora com mais esta.
#
# HAPPY Amen and Amen ðð½
#
# FEAR It's a PELOSI production the whole thing even the dead girl pelosi Sacraficed lamb ..Pelosi daughter married to a producer he was seen with antifa bunch pics n all today ð¤
#
# SURPRISE iâm still skeptical anytime someone claims to be a woman on the internet. iâm old school. there used to be literally 0 women on the internet
#
# ANGRY Give me an Echo if you're still with Trump.
#
# HAPPY BOOM!!!!!!!!!!
#
# FEAR Do You Carry? If Not, Start Thinking About It..
#
# DISGUST SHREDDED BALLOTS FOUND IN GA ALREADY! Gen FLYNN
#
# HAPPY I could not agree more.The best is yet to come.
#
# SURPRISE ð¥ ECHO!ð Follow <a href="/profile/WeLoveTrump/posts" class="at"><a href="/profile/WeLoveTrump/posts" class="at">@WeLoveTrump</a></a> for more!
#
# HAPPY â¤ï¸ðºð¸ð¯ð
#
# SURPRISE Ossoff, after being down by 120,000 votes with 91% in, just tied Perdue.Well, let's see how these Republican Senators vote tomorrow knowing they need Trump to win to keep their majority.
#
# ANGRY PEDO ALERT!!!!
#
# SURPRISE He was NOT expecting that ðð
#
# FEAR Where was tolerance and sacred ritual when Trump was elected?
#
# SURPRISE Law enforcement officials across the U.S. shocked by police failure to stop Capitol invasion
#
# SAD These words could be said tonight in a slightly different way by President Trump to America.âMy brave fellows, you have done all I asked you to do, and more than can be reasonably expected; but your country is at stake, your wives, your houses and all that you hold dear. You have worn yourselves out with fatigues and hardships, but we know not how to spare you. If you will consent to stay one month longer, you will render that service to the cause of liberty, and to your country, which you probably can never do under any other circumstances."WASHINGTON, ENCOURAGING HIS MEN TO RE-ENLIST IN THE ARMY | TUESDAY, DECEMBER 31, 1776
#
# FEAR Our country is in the middle of a planned coup. To overthrow the duly elected President, Donald Trump.The ringleaders are Pence, Pelosi, & McConnell. It is all done as part of CCP color revolution.What to do? Ignore the lies. Stay 80M+ strong in supporting Trump. Pray for God to save us. On his time, He will.All will be well. Trust the Lord.
#
# DISGUST Same shit different day
#
# FEAR â¼ï¸â¼ï¸ Since #twitter and #fakebook have taken down my speech, here it is !! Share widely â¼ï¸â¼ï¸ #stopthesteal #stopthecoup #stopthecensorship #fakenews #stopthebias
#
# ANGRY TRUMP in DC: âWe Will Never Give Up, We Will Never Concede, Our Country Has Had Enoughâ
#
# SURPRISE The President of the United States of America was tweeting out CALLS for PEACE on Twitter. His account has now been 'locked' for 12-hours.#1776#Section230#saveamerica
#
# SURPRISE President Donald Trump has sparked intense debate over Mike Penceâs role in Congressâ certification of the Electoral College votes, as he seemingly called on the vice president to reject âfraudulent electors.â
#
# ANGRY History repeating itself. When Twitter and Facebook try to take President Trumpâs accounts down. They tried to silence Reagan. We are not going to take it! Trump fights for us just like Reagan did.
#
# FEAR Remember this?Kamala Harris:âEveryone, beware. [Protestors] are not going to stop before Election Day in November and theyâre not going to stop after Election Day,â Harris added that âthey should notâ and âwe should not.âShe said this with a smile on her face!
#
# ANGRY FALSE FLAGS ð THIS IS ANTIFAHEAVILY ARMED SWAT & FBI ENTERING CAPITAL NOW
#
# SAD âBiden Is Our President Like Maduro Is Venezuela's.â Crushing article by @DebbieDSouza in El American
#
# FEAR Parler just crashed for me. Lots of people who dont want the signal to be broadcasted!!!Link below on ways to protect yourself from this Wifi assault
#
# SURPRISE Why are they stopping the vote count in Democrat Chatham county, Georgia?This sounds familiar! ð¤¨
#
# DISGUST Fuck you assholes you try to install a criminal as President of the United States fuck you
#
# ANGRY Military is the only way.
#
# SURPRISE Special Edition - Real America - Georgia Senate Runoffs #OANN
#
# DISGUST Own it âPatriotsâ.Own getting someone killed over your bullshit. Own the removal of the America flag to hang the name of your leader.Own that you are not Patriots, you are terrorists.
#
# FEAR Our country is in the middle of a planned coup. To overthrow the duly elected President, Donald Trump.The ringleaders are Pence, Pelosi, & McConnell. It is all done as part of CCP color revolution.What to do? Ignore the lies. Stay 80M+ strong in supporting Trump. Pray for God to save us. On his time, He will.All will be well. Trust the Lord.
#
# HAPPY ECHO
#
# FEAR Democrat counties in Georgia just stopped counting ballots for the nightThis is why people have no faith in our election systemSounds just like what happened in November to President Trum
#
# HAPPY 5 million in D.C tonight! We love you President Trump and 80+ million Patriots are behind you! You won in a landslide on election day and the world will know it tomorrow! God bless you, God bless all Patriots! ðºð¸ðºð¸WWG1WGA TRUMP2020ð½
#
# FEAR More on election fraud
#
# HAPPY Letâs go Patriots!!! ðð¼ðªð¼ðºð¸ðºð¸ðºð¸
#
# HAPPY Nice patriots giving mittens a piece of your mind
#
# DISGUST PIECE OF SHIT!!!!
#
# SURPRISE We have our first challenge, #PaulGosar has challenged #Arizona, and it is signed by a senator! #Republicans in congress are applauding!
#
# ANGRY Bidenâ really? This is a pretty peaceful protest considering. We arenât even sure if it was Antifa or BLM who fired shots. Trump supporters arenât burning, looting, or being violent. We donât want you to be our president!!! We didnât elect you!! We were robbed of our right to vote! If circumstances were turned... we would see so much more violence and death. We have seen so much worse from pissed off liberals.
#
# HAPPY HOLD THE LINE, PATRIOTS! ðºð¸ ðºð¸ ðºð¸ ðºð¸ ðºð¸ ðºð¸ We will win! â¤ï¸â¤ï¸â¤ï¸
#
# HAPPY Nice BLUE tie Mike ð¤¬ð¤¬ð¤¬ð¤¬
#
# SAD If Ossof actually wins the Ga senate seat, the country I have loved for my enire life, 71 years, will be destroyed. The only hope we will have is 2022 election. May God direct our paths.
#
# SURPRISE Amazing!!! ðð»ðºð¸ð¬ð§
#
# HAPPY Please donât echo
#
# HAPPY 1/6/2020DC
#
# ANGRY ð¥ Tulsi torches Nancy
#
# SAD Poor Liberals and Aunty Tifa will never understand a group of patriots standing up and breaking out into an impromptu National Anthem.Washington Marriott at Metro Center.DC. January 5, 2021.#SayIt#marchfortrump#saveamerica*Tammy C reporting
#
# DISGUST DAMN OBAMA ð¤¬ð¤¬ð¤¬
#
# SURPRISE Statement from President DonaldTrum
#
# SURPRISE Follow  @Name Hidden  and echo if you agree!
#
# DISGUST Oh my gosh-I switched over to see what fox was reporting ð¤ What a bunch of drama queens! They sure didnât act that way when BLM and Antifa were burning down buildings. Idiots! Dana, Brett and Chris Wallace what a bunch of one sided idiots!ð¡ This country is done with Fox News.
#
# FEAR #GREATRESET #FREEDOMFROMTHEPRESS #gaetztakes #dobbs #RESIST #WHO #fakenews #Sheeple #hunterbiden #holdtheline #pandemic #election #stopthefraud #politics #Trump #Biden #Republican #Republicans #Democrat #Democrats #Liberal #Liberals #Progressive #Progressives #Libertarian #Libertarians #RINO #GOP #speech #debate #liberty #freedom #cancelculture #potus #parlerusa #dominion #fightback #stopthesteal
#
# FEAR Mitch McConnell will have learned a valuable lesson this day.The GOP didn't grow because of anything "Republicans" did. If and when Trump steps off the main stage, he will be more powerful than he ever was as defacto GOP leader. He told those who turned their backs â Remember.
#
# HAPPY James O'Keefe will never stop trying to expose corruption. Thank you Sir.
#
# FEAR And just like that, 80M patriots vowed to never do business with Bank of America. #SayIt #bankofamerica
#
# FEAR [P]atriots [A]re [N]ow [I]n [C]ontrol = PANIC IN DC
#
# ANGRY ABL LIVE
#
# DISGUST Pence is a traitor. Check rob and Lin posts
#
# DISGUST This is crazy!!!
#
# SURPRISE Georgia Poll Worker Says She Found âPristineâ Batch of Ballots That Went â98%â for Biden
#
# ANGRY Jim Jordan Goes BEAST MODE on House Floor, Confronts Dems on ElectionWell said Jim Jordan
#
# SURPRISE Developing: Facial recognition firm claims antifa infiltrated Trump protesters who stormed Capitol washingtontimes.com/news/2021/jan/â¦ via <a href="/profile/washtimes/posts" class="at">@washtimes</a
#
# ANGRY Socialism is Regressive and Destroys Societies
#
# HAPPY FreeRoots
#
# DISGUST That have raised hoodlums for children. They look ð¿ demonic.
#
# SAD The Republican Party is dying A slow death in the last 2 months tomorrow should seal their fate. The Patriot party must form!
#
# HAPPY a href="/profile/TedCruz/posts" class="at">@TedCruz</a> is the definition of a true Patriot. He says he's going to do it, AND DOES IT! He's been one of the few to have not only Trumps back, but the American peoples' back. He's proved this many times. Thank you, Mr. Cruz! Patriots will forever have your backððºð¸ECHO IF YOU BACK TED CRUZ!
#
# HAPPY THIS IS ART!!!
#
# SURPRISE ð¨GOOD QUESTION, MARKð¨...BALLOT STUFFING TAKES LONGER?ð¤ð¤¨
#
# FEAR Do you really want a country where the decision to overturn a presidential election rests in the hands of just one man? What if that man was a swampbeast? We win a different way.
#
# SURPRISE Matt Gaetz stands tallâ¦ â CITIZEN FREE PRESS
#
# DISGUST Calif Gov is dirty
#
# FEAR Now We The People better understand the past four years & the crimes perpetrated against our country by others. Rod Rosenstein must be arrested today.
#
# ANGRY Some of us will stay here through the night. To show you that we have balls and we dont care its a federal building its ours anyway. No destruction here. If antifa is present they will pay for the damage not us. Echo and follow me. We mean business when we say we want to save america
#
# SAD WE KNEW THAT.But thanks.We also know our country is at war.#Antifa#saveamerica
#
# SURPRISE ANTIFA/BLMWELL THIS IS INTERESTING IF TRUE.And it wouldnât surprise me at all if it was.Swipe picture left.Thanks to the person who brought this to my attention.
#
# SURPRISE Ron@CodeMonkeyZ:Obama and ministry of Italy altered voting systems. Itâs over. We got emâ! Tomorrow should be epic!!!
#
# SURPRISE BUSTED: Project Veritas CONFRONTS Central Night Shelter Board Member Adam Seeley #GAVoterFraud - YouTubeGET THIS ECHOED VIRALLY!!!!!!!!!! Make this go viral!#ProjectVeritas #makethisgoviral #viral #DeclassifyEverything #WeThePeople #USA #1A #AmericaFirst #DeclareMartialLaw #MartialLaw #InsurrectionAct #FightBack #FightLikeAFlynn #DoNotConcede #HoldTheLine #StopTheSteal #Trump2020 #GodBlessAmerica #12thAmendment #Trending
#
# HAPPY HELL YEAH!! LETS GET R DONE....WHOEVER AGREES, ECHO THIS... ðºð¸ â¥ï¸
#
# FEAR SWAMP BEING EXPOSED
#
# HAPPY FOLLOW & ECHO ðºð¸ð¦ð
#
# DISGUST Letâs face it. This rigged election goes soooo deep. How do they do it? Already votes taken away from candidates, bus loads of voters coming in to GA to vote. What a farce!
#
# SAD PUT AWAY social media and TURN OFF any news outlet. We are way too emotional to be posting and commenting on peopleâs stuff right now. Just take a deep breathe and get in your prayer room. Come back when youâve been filled with His presence and love.
#
# ANGRY Time to go after the Deepstate Rothschilds - Soros and the rest of the Elites with Pitchforks/ Torches and Ropes. Time to burn ð¥ The whole freaking establishment down.
#
# 23.484152793884277
