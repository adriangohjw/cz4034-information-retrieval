# %%
from sklearn.model_selection import train_test_split
import pandas as pd
from transformers import RobertaTokenizer
import torch
from tqdm import tqdm
torch.cuda.empty_cache()
import numpy as np
from sklearn.metrics import f1_score

# %%
df.head()
# Out:
#    Unnamed: 0                                               text subjectivity  \
# 0           0                                 Love our President  OPINIONATED
# 1           1                                  Yes, same guy!!!!      NEUTRAL
# 2           2  Thank God we Parlerðâï¸ðºð¸.I'm grat...  OPINIONATED
# 3           3  This would be the best case scenario, Wednesda...      NEUTRAL
# 4           4  Sharpton is as non-partisan as lions are veget...      NEUTRAL
#
#    polarity
# 0  POSITIVE
# 1       NaN
# 2  POSITIVE
# 3       NaN
# 4       NaN

# %%
labels_dict = {'POSITIVE':0, 'NEGATIVE':1}
df = pd.read_csv('../data/cleaned_subj_polar__.csv', encoding='ISO-8859-1')
df = df.loc[df['subjectivity']=='OPINIONATED']
df['label'] = df['polarity'].apply(lambda x: labels_dict[x])
print(len(df))
df.head()
# Out:
# 600
#     Unnamed: 0                                               text  \
# 0            0                                 Love our President
# 2            2  Thank God we Parlerðâï¸ðºð¸.I'm grat...
# 6            6  The Photag has conveniently left out every ide...
# 12          12  I admire you tremendously! Smart, quick witted...
# 14          14  You hit the nsil on the head...I'm tired of he...
#
#    subjectivity  polarity  label
# 0   OPINIONATED  POSITIVE      0
# 2   OPINIONATED  POSITIVE      0
# 6   OPINIONATED  NEGATIVE      1
# 12  OPINIONATED  POSITIVE      0
# 14  OPINIONATED  NEGATIVE      1

# %%
text = list(df.text)
labels = list(df.label)
train_texts, val_texts, train_labels, val_labels = train_test_split(text, labels, test_size=.15, stratify=labels)

# %%
from torch.utils.data import TensorDataset
from transformers import BertTokenizer

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased',
                                          do_lower_case=True)

# %%
train_encode = tokenizer.batch_encode_plus(
    train_texts,
    add_special_tokens=True,
    padding=True,
    truncation = True,
    max_length = 256,   
    return_tensors='pt'
)

valid_encode = tokenizer.batch_encode_plus(
    val_texts,
    add_special_tokens=True,
    padding=True,
    truncation = True,
    max_length = 256,   
    return_tensors='pt'
)
valid_input = valid_encode['input_ids']
valid_attention = valid_encode['attention_mask']
valid_labels = torch.tensor(val_labels)

input_ids = train_encode['input_ids']
attention_mask = train_encode['attention_mask']
labels = torch.tensor(train_labels)

# %%
train_data = TensorDataset(input_ids,
                          attention_mask,
                          labels)

valid_data = TensorDataset(valid_input,
                          valid_attention,
                          valid_labels)

# %%
from transformers import BertForSequenceClassification

#Finetuning pretrained BERT model with objective -> Sentence Classification
model = BertForSequenceClassification.from_pretrained('bert-base-uncased',
                                                      num_labels = 2,
                                                      output_attentions=False,
                                                      output_hidden_states=False)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler

BATCH_SIZE = 8

train_dataloader = DataLoader(train_data,
                              sampler = RandomSampler(train_data),
                              batch_size = BATCH_SIZE)
valid_dataloader = DataLoader(valid_data,
                              sampler = SequentialSampler(valid_data),
                              batch_size = BATCH_SIZE)

# %%
from transformers import AdamW, get_cosine_schedule_with_warmup

#Works better than torch.optim.Adam
optimizer = AdamW(model.parameters(),
                           lr=1e-5,
                           eps=1e-6,
                           weight_decay=1e-1)
#chosen after setting = 3 (f1 -> 0.71), 5 (f1 -> 0.77) but acpc for many classes is 0
#10 Epochs helps with generalization
EPOCHS = 10 

#Works better than torch.optim.CosineAnnealingLR and transformers.get_linear_schedule_with_warmup
scheduler = get_cosine_schedule_with_warmup(optimizer,
                                            num_warmup_steps = 0,
                                            num_training_steps=len(train_dataloader)*EPOCHS)

# %%
def f1(preds, labels):
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return f1_score(labels_flat, preds_flat, average='weighted')

# %%
#Per Class Accuracy
def acpc(preds, labels):
    code_dict = {val:key for key,val in labels_dict.items()}

    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()

    for idx in np.unique(labels_flat):
        y_hat = preds_flat[labels_flat==idx]
        y = labels_flat[labels_flat==idx]
        print(f'Class: {code_dict[idx]}')
        print(f'Accuracy: {len(y_hat[y_hat==idx])/ len(y)}\n')

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

print(device)
# Out:
# cuda

# %%
def evaluate(valid_dataloader):
    model.eval()

    total_eval_loss = 0
    y_hat, y = [], []

    for batch in valid_dataloader:
        batch = tuple(b.to(device) for b in batch)

        inputs = {'input_ids' : batch[0],
                'attention_mask': batch[1],
                'labels' : batch[2]
                }
        with torch.no_grad():
            outputs = model(**inputs)

        loss = outputs[0]
        logits = outputs[1]
        total_eval_loss += loss.item()

        logits = logits.detach().cpu().numpy()
        label_ids = inputs['labels'].cpu().numpy()
        y_hat.append(logits)
        y.append(label_ids)

    avg_eval_loss = total_eval_loss/len(valid_dataloader) 

    y_hat = np.concatenate(y_hat, axis=0)
    y = np.concatenate(y, axis=0)
            
    return avg_eval_loss, y_hat, y

# %%
vloss = []
score = []
for epoch in tqdm(range(1, EPOCHS+1)):
    model.train()

    total_loss = 0

    progress_bar = tqdm(train_dataloader, desc='Epoch {:1d}'.format(epoch), leave=False, disable=False)
    for batch in progress_bar:
        model.zero_grad()

        batch = tuple(b.to(device) for b in batch)
        inputs = {'input_ids' : batch[0],
                  'attention_mask': batch[1],
                  'labels' : batch[2]
                  }
        outputs = model(**inputs)
        loss = outputs[0]
        total_loss += loss.item()
        loss.backward()

        optimizer.step()
        scheduler.step()

        progress_bar.set_postfix({'training_loss': '{:.3f}'.format(loss.item()/len(batch))})

    torch.save(model.state_dict(), f'./bert polarity/BERT_polarity_epoch_{epoch}.pt')

    tqdm.write(f'\nEpoch {epoch}')

    avg_training_loss = total_loss/len(train_dataloader)            
    tqdm.write(f'Training loss: {avg_training_loss}')

    val_loss, predictions, actual = evaluate(valid_dataloader)
    score_f1 = f1(predictions, actual)
    tqdm.write(f'Validation loss: {val_loss}')
    tqdm.write(f'F1 Score (Weighted): {score_f1}')
    vloss.append(val_loss)
    score.append(score_f1)
# Out:
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
# Epoch 1:   0%|                                                                                  | 0/64 [00:00<?, ?it/s]
# Epoch 1:   0%|                                                             | 0/64 [00:00<?, ?it/s, training_loss=0.268]
# Epoch 1:   2%|▊                                                    | 1/64 [00:00<01:00,  1.05it/s, training_loss=0.268]
# Epoch 1:   2%|▊                                                    | 1/64 [00:01<01:00,  1.05it/s, training_loss=0.257]
# Epoch 1:   3%|█▋                                                   | 2/64 [00:01<00:43,  1.42it/s, training_loss=0.257]
# Epoch 1:   3%|█▋                                                   | 2/64 [00:01<00:43,  1.42it/s, training_loss=0.231]
# Epoch 1:   5%|██▍                                                  | 3/64 [00:01<00:37,  1.63it/s, training_loss=0.231]
# Epoch 1:   5%|██▍                                                  | 3/64 [00:02<00:37,  1.63it/s, training_loss=0.244]
# Epoch 1:   6%|███▎                                                 | 4/64 [00:02<00:34,  1.73it/s, training_loss=0.244]
# Epoch 1:   6%|███▎                                                 | 4/64 [00:03<00:34,  1.73it/s, training_loss=0.257]
# Epoch 1:   8%|████▏                                                | 5/64 [00:03<00:33,  1.78it/s, training_loss=0.257]
# Epoch 1:   8%|████▏                                                | 5/64 [00:03<00:33,  1.78it/s, training_loss=0.221]
# Epoch 1:   9%|████▉                                                | 6/64 [00:03<00:31,  1.82it/s, training_loss=0.221]
# Epoch 1:   9%|████▉                                                | 6/64 [00:04<00:31,  1.82it/s, training_loss=0.217]
# Epoch 1:  11%|█████▊                                               | 7/64 [00:04<00:30,  1.86it/s, training_loss=0.217]
# Epoch 1:  11%|█████▊                                               | 7/64 [00:04<00:30,  1.86it/s, training_loss=0.225]
# Epoch 1:  12%|██████▋                                              | 8/64 [00:04<00:29,  1.87it/s, training_loss=0.225]
# Epoch 1:  12%|██████▋                                              | 8/64 [00:05<00:29,  1.87it/s, training_loss=0.242]
# Epoch 1:  14%|███████▍                                             | 9/64 [00:05<00:29,  1.88it/s, training_loss=0.242]
# Epoch 1:  14%|███████▍                                             | 9/64 [00:05<00:29,  1.88it/s, training_loss=0.221]
# Epoch 1:  16%|████████▏                                           | 10/64 [00:05<00:28,  1.88it/s, training_loss=0.221]
# Epoch 1:  16%|████████▏                                           | 10/64 [00:06<00:28,  1.88it/s, training_loss=0.220]
# Epoch 1:  17%|████████▉                                           | 11/64 [00:06<00:27,  1.91it/s, training_loss=0.220]
# Epoch 1:  17%|████████▉                                           | 11/64 [00:06<00:27,  1.91it/s, training_loss=0.237]
# Epoch 1:  19%|█████████▊                                          | 12/64 [00:06<00:27,  1.91it/s, training_loss=0.237]
# Epoch 1:  19%|█████████▊                                          | 12/64 [00:07<00:27,  1.91it/s, training_loss=0.207]
# Epoch 1:  20%|██████████▌                                         | 13/64 [00:07<00:26,  1.91it/s, training_loss=0.207]
# Epoch 1:  20%|██████████▌                                         | 13/64 [00:07<00:26,  1.91it/s, training_loss=0.236]
# Epoch 1:  22%|███████████▍                                        | 14/64 [00:07<00:26,  1.90it/s, training_loss=0.236]
# Epoch 1:  22%|███████████▍                                        | 14/64 [00:08<00:26,  1.90it/s, training_loss=0.226]
# Epoch 1:  23%|████████████▏                                       | 15/64 [00:08<00:25,  1.92it/s, training_loss=0.226]
# Epoch 1:  23%|████████████▏                                       | 15/64 [00:08<00:25,  1.92it/s, training_loss=0.202]
# Epoch 1:  25%|█████████████                                       | 16/64 [00:08<00:25,  1.91it/s, training_loss=0.202]
# Epoch 1:  25%|█████████████                                       | 16/64 [00:09<00:25,  1.91it/s, training_loss=0.220]
# Epoch 1:  27%|█████████████▊                                      | 17/64 [00:09<00:24,  1.90it/s, training_loss=0.220]
# Epoch 1:  27%|█████████████▊                                      | 17/64 [00:09<00:24,  1.90it/s, training_loss=0.227]
# Epoch 1:  28%|██████████████▋                                     | 18/64 [00:09<00:24,  1.90it/s, training_loss=0.227]
# Epoch 1:  28%|██████████████▋                                     | 18/64 [00:10<00:24,  1.90it/s, training_loss=0.227]
# Epoch 1:  30%|███████████████▍                                    | 19/64 [00:10<00:23,  1.92it/s, training_loss=0.227]
# Epoch 1:  30%|███████████████▍                                    | 19/64 [00:10<00:23,  1.92it/s, training_loss=0.228]
# Epoch 1:  94%|████████████████████████████████████████████████▊   | 60/64 [00:32<00:02,  1.90it/s, training_loss=0.058]
# Epoch 1:  95%|█████████████████████████████████████████████████▌  | 61/64 [00:32<00:01,  1.93it/s, training_loss=0.058]
# Epoch 1:  95%|█████████████████████████████████████████████████▌  | 61/64 [00:32<00:01,  1.93it/s, training_loss=0.061]
# Epoch 1:  97%|██████████████████████████████████████████████████▍ | 62/64 [00:32<00:01,  1.93it/s, training_loss=0.061]
# Epoch 1:  97%|██████████████████████████████████████████████████▍ | 62/64 [00:33<00:01,  1.93it/s, training_loss=0.062]
# Epoch 1:  98%|███████████████████████████████████████████████████▏| 63/64 [00:33<00:00,  1.92it/s, training_loss=0.062]
# Epoch 1:  98%|███████████████████████████████████████████████████▏| 63/64 [00:33<00:00,  1.92it/s, training_loss=0.057]
# Epoch 1: 100%|████████████████████████████████████████████████████| 64/64 [00:33<00:00,  2.03it/s, training_loss=0.057]
#   0%|                                                                                           | 0/10 [00:35<?, ?it/s]
# Epoch 1
# Training loss: 0.495698748389259
#  10%|████████▎                                                                          | 1/10 [00:36<05:29, 36.59s/it]
# Epoch 2:   0%|                                                                                  | 0/64 [00:00<?, ?it/s]
# Validation loss: 0.15310885570943356
# F1 Score (Weighted): 1.0
# Epoch 2:   0%|                                                             | 0/64 [00:00<?, ?it/s, training_loss=0.054]
# Epoch 2:   2%|▊                                                    | 1/64 [00:00<00:33,  1.89it/s, training_loss=0.054]
# Epoch 2:   2%|▊                                                    | 1/64 [00:01<00:33,  1.89it/s, training_loss=0.051]
# Epoch 2:   3%|█▋                                                   | 2/64 [00:01<00:32,  1.89it/s, training_loss=0.051]
# Epoch 2:   3%|█▋                                                   | 2/64 [00:01<00:32,  1.89it/s, training_loss=0.053]
# Epoch 2:   5%|██▍                                                  | 3/64 [00:01<00:31,  1.91it/s, training_loss=0.053]
# Epoch 2:   5%|██▍                                                  | 3/64 [00:02<00:31,  1.91it/s, training_loss=0.047]
# Epoch 2:   6%|███▎                                                 | 4/64 [00:02<00:31,  1.89it/s, training_loss=0.047]
# Epoch 2:   6%|███▎                                                 | 4/64 [00:02<00:31,  1.89it/s, training_loss=0.051]
# Epoch 2:   8%|████▏                                                | 5/64 [00:02<00:31,  1.90it/s, training_loss=0.051]
# Epoch 2:   8%|████▏                                                | 5/64 [00:03<00:31,  1.90it/s, training_loss=0.045]
# Epoch 2:   9%|████▉                                                | 6/64 [00:03<00:30,  1.88it/s, training_loss=0.045]
# Epoch 2:   9%|████▉                                                | 6/64 [00:03<00:30,  1.88it/s, training_loss=0.038]
# Epoch 2:  11%|█████▊                                               | 7/64 [00:03<00:30,  1.87it/s, training_loss=0.038]
# Epoch 2:  11%|█████▊                                               | 7/64 [00:04<00:30,  1.87it/s, training_loss=0.039]
# Epoch 2:  12%|██████▋                                              | 8/64 [00:04<00:29,  1.88it/s, training_loss=0.039]
# Epoch 2:  12%|██████▋                                              | 8/64 [00:04<00:29,  1.88it/s, training_loss=0.037]
# Epoch 2:  14%|███████▍                                             | 9/64 [00:04<00:29,  1.87it/s, training_loss=0.037]
# Epoch 2:  14%|███████▍                                             | 9/64 [00:05<00:29,  1.87it/s, training_loss=0.031]
# Epoch 2:  16%|████████▏                                           | 10/64 [00:05<00:28,  1.88it/s, training_loss=0.031]
# Epoch 2:  16%|████████▏                                           | 10/64 [00:05<00:28,  1.88it/s, training_loss=0.031]
# Epoch 2:  17%|████████▉                                           | 11/64 [00:05<00:27,  1.90it/s, training_loss=0.031]
# Epoch 2:  17%|████████▉                                           | 11/64 [00:06<00:27,  1.90it/s, training_loss=0.068]
# Epoch 2:  19%|█████████▊                                          | 12/64 [00:06<00:27,  1.90it/s, training_loss=0.068]
# Epoch 2:  19%|█████████▊                                          | 12/64 [00:06<00:27,  1.90it/s, training_loss=0.036]
# Epoch 2:  20%|██████████▌                                         | 13/64 [00:06<00:27,  1.87it/s, training_loss=0.036]
# Epoch 2:  20%|██████████▌                                         | 13/64 [00:07<00:27,  1.87it/s, training_loss=0.038]
# Epoch 2:  22%|███████████▍                                        | 14/64 [00:07<00:26,  1.87it/s, training_loss=0.038]
# Epoch 2:  22%|███████████▍                                        | 14/64 [00:07<00:26,  1.87it/s, training_loss=0.051]
# Epoch 2:  23%|████████████▏                                       | 15/64 [00:07<00:26,  1.85it/s, training_loss=0.051]
# Epoch 2:  23%|████████████▏                                       | 15/64 [00:08<00:26,  1.85it/s, training_loss=0.027]
# Epoch 2:  25%|█████████████                                       | 16/64 [00:08<00:25,  1.86it/s, training_loss=0.027]
# Epoch 2:  25%|█████████████                                       | 16/64 [00:09<00:25,  1.86it/s, training_loss=0.043]
# Epoch 2:  27%|█████████████▊                                      | 17/64 [00:09<00:25,  1.86it/s, training_loss=0.043]
# Epoch 2:  27%|█████████████▊                                      | 17/64 [00:09<00:25,  1.86it/s, training_loss=0.019]
# Epoch 2:  28%|██████████████▋                                     | 18/64 [00:09<00:24,  1.88it/s, training_loss=0.019]
# Epoch 2:  28%|██████████████▋                                     | 18/64 [00:10<00:24,  1.88it/s, training_loss=0.031]
# Epoch 2:  30%|███████████████▍                                    | 19/64 [00:10<00:23,  1.89it/s, training_loss=0.031]
# Epoch 2:  30%|███████████████▍                                    | 19/64 [00:10<00:23,  1.89it/s, training_loss=0.028]
# Epoch 2:  31%|████████████████▎                                   | 20/64 [00:10<00:23,  1.86it/s, training_loss=0.028]
# Epoch 2:  31%|████████████████▎                                   | 20/64 [00:11<00:23,  1.86it/s, training_loss=0.028]
# Epoch 2:  33%|█████████████████                                   | 21/64 [00:11<00:23,  1.84it/s, training_loss=0.028]
# Epoch 2:  33%|█████████████████                                   | 21/64 [00:11<00:23,  1.84it/s, training_loss=0.021]
# Epoch 2:  34%|█████████████████▉                                  | 22/64 [00:11<00:22,  1.87it/s, training_loss=0.021]
# Epoch 2:  34%|█████████████████▉                                  | 22/64 [00:12<00:22,  1.87it/s, training_loss=0.018]
# Epoch 2:  36%|██████████████████▋                                 | 23/64 [00:12<00:21,  1.87it/s, training_loss=0.018]
# Epoch 2:  98%|███████████████████████████████████████████████████▏| 63/64 [00:34<00:00,  1.78it/s, training_loss=0.012]
# Epoch 2: 100%|████████████████████████████████████████████████████| 64/64 [00:34<00:00,  1.90it/s, training_loss=0.012]
#  10%|████████▎                                                                          | 1/10 [01:13<05:29, 36.59s/it]
# Epoch 2
# Training loss: 0.07553183051641099
#  20%|████████████████▌                                                                  | 2/10 [01:14<04:57, 37.24s/it]
# Epoch 3:   0%|                                                                                  | 0/64 [00:00<?, ?it/s]
# Validation loss: 0.022375446899483602
# F1 Score (Weighted): 1.0
# Epoch 3:   0%|                                                             | 0/64 [00:00<?, ?it/s, training_loss=0.007]
# Epoch 3:   2%|▊                                                    | 1/64 [00:00<00:34,  1.85it/s, training_loss=0.007]
# Epoch 3:   2%|▊                                                    | 1/64 [00:01<00:34,  1.85it/s, training_loss=0.008]
# Epoch 3:   3%|█▋                                                   | 2/64 [00:01<00:33,  1.85it/s, training_loss=0.008]
# Epoch 3:   3%|█▋                                                   | 2/64 [00:01<00:33,  1.85it/s, training_loss=0.008]
# Epoch 3:   5%|██▍                                                  | 3/64 [00:01<00:33,  1.85it/s, training_loss=0.008]
# Epoch 3:   5%|██▍                                                  | 3/64 [00:02<00:33,  1.85it/s, training_loss=0.007]
# Epoch 3:   6%|███▎                                                 | 4/64 [00:02<00:31,  1.89it/s, training_loss=0.007]
# Epoch 3:   6%|███▎                                                 | 4/64 [00:02<00:31,  1.89it/s, training_loss=0.007]
# Epoch 3:   8%|████▏                                                | 5/64 [00:02<00:31,  1.89it/s, training_loss=0.007]
# Epoch 3:   8%|████▏                                                | 5/64 [00:03<00:31,  1.89it/s, training_loss=0.007]
# Epoch 3:   9%|████▉                                                | 6/64 [00:03<00:30,  1.89it/s, training_loss=0.007]
# Epoch 3:   9%|████▉                                                | 6/64 [00:03<00:30,  1.89it/s, training_loss=0.006]
# Epoch 3:  11%|█████▊                                               | 7/64 [00:03<00:30,  1.90it/s, training_loss=0.006]
# Epoch 3:  11%|█████▊                                               | 7/64 [00:04<00:30,  1.90it/s, training_loss=0.008]
# Epoch 3:  12%|██████▋                                              | 8/64 [00:04<00:29,  1.91it/s, training_loss=0.008]
# Epoch 3:  12%|██████▋                                              | 8/64 [00:04<00:29,  1.91it/s, training_loss=0.006]
# Epoch 3:  14%|███████▍                                             | 9/64 [00:04<00:28,  1.91it/s, training_loss=0.006]
# Epoch 3:  14%|███████▍                                             | 9/64 [00:05<00:28,  1.91it/s, training_loss=0.007]
# Epoch 3:  16%|████████▏                                           | 10/64 [00:05<00:28,  1.89it/s, training_loss=0.007]
# Epoch 3:  16%|████████▏                                           | 10/64 [00:05<00:28,  1.89it/s, training_loss=0.005]
# Epoch 3:  17%|████████▉                                           | 11/64 [00:05<00:27,  1.90it/s, training_loss=0.005]
# Epoch 3:  17%|████████▉                                           | 11/64 [00:06<00:27,  1.90it/s, training_loss=0.008]
# Epoch 3:  19%|█████████▊                                          | 12/64 [00:06<00:27,  1.89it/s, training_loss=0.008]
# Epoch 3:  19%|█████████▊                                          | 12/64 [00:06<00:27,  1.89it/s, training_loss=0.006]
# Epoch 3:  20%|██████████▌                                         | 13/64 [00:06<00:27,  1.88it/s, training_loss=0.006]
# Epoch 3:  20%|██████████▌                                         | 13/64 [00:07<00:27,  1.88it/s, training_loss=0.008]
# Epoch 3:  22%|███████████▍                                        | 14/64 [00:07<00:26,  1.86it/s, training_loss=0.008]
# Epoch 3:  22%|███████████▍                                        | 14/64 [00:07<00:26,  1.86it/s, training_loss=0.006]
# Epoch 3:  23%|████████████▏                                       | 15/64 [00:07<00:26,  1.88it/s, training_loss=0.006]
# Epoch 3:  23%|████████████▏                                       | 15/64 [00:08<00:26,  1.88it/s, training_loss=0.007]
# Epoch 3:  25%|█████████████                                       | 16/64 [00:08<00:26,  1.85it/s, training_loss=0.007]
# Epoch 3:  25%|█████████████                                       | 16/64 [00:09<00:26,  1.85it/s, training_loss=0.160]
# Epoch 3:  27%|█████████████▊                                      | 17/64 [00:09<00:25,  1.81it/s, training_loss=0.160]
# Epoch 3:  27%|█████████████▊                                      | 17/64 [00:09<00:25,  1.81it/s, training_loss=0.005]
# Epoch 3:  28%|██████████████▋                                     | 18/64 [00:09<00:25,  1.83it/s, training_loss=0.005]
# Epoch 3:  28%|██████████████▋                                     | 18/64 [00:10<00:25,  1.83it/s, training_loss=0.006]
# Epoch 3:  30%|███████████████▍                                    | 19/64 [00:10<00:24,  1.83it/s, training_loss=0.006]
# Epoch 3:  30%|███████████████▍                                    | 19/64 [00:10<00:24,  1.83it/s, training_loss=0.007]
# Epoch 3:  31%|████████████████▎                                   | 20/64 [00:10<00:24,  1.82it/s, training_loss=0.007]
# Epoch 3:  31%|████████████████▎                                   | 20/64 [00:11<00:24,  1.82it/s, training_loss=0.006]
# Epoch 3:  33%|█████████████████                                   | 21/64 [00:11<00:23,  1.82it/s, training_loss=0.006]
# Epoch 3:  33%|█████████████████                                   | 21/64 [00:11<00:23,  1.82it/s, training_loss=0.006]
# Epoch 3:  34%|█████████████████▉                                  | 22/64 [00:11<00:22,  1.85it/s, training_loss=0.006]
# Epoch 3:  34%|█████████████████▉                                  | 22/64 [00:12<00:22,  1.85it/s, training_loss=0.006]
# Epoch 3:  36%|██████████████████▋                                 | 23/64 [00:12<00:22,  1.85it/s, training_loss=0.006]
# Epoch 3:  36%|██████████████████▋                                 | 23/64 [00:12<00:22,  1.85it/s, training_loss=0.006]
# Epoch 3:  38%|███████████████████▌                                | 24/64 [00:12<00:21,  1.84it/s, training_loss=0.006]
# Epoch 3:  38%|███████████████████▌                                | 24/64 [00:13<00:21,  1.84it/s, training_loss=0.005]
# Epoch 3:  39%|████████████████████▎                               | 25/64 [00:13<00:21,  1.84it/s, training_loss=0.005]
# Epoch 3:  39%|████████████████████▎                               | 25/64 [00:13<00:21,  1.84it/s, training_loss=0.006]
# Epoch 3:  41%|█████████████████████▏                              | 26/64 [00:13<00:20,  1.87it/s, training_loss=0.006]
# Epoch 3:  41%|█████████████████████▏                              | 26/64 [00:14<00:20,  1.87it/s, training_loss=0.005]
# Epoch 3:  42%|█████████████████████▉                              | 27/64 [00:14<00:19,  1.85it/s, training_loss=0.005]
# Epoch 3:  42%|█████████████████████▉                              | 27/64 [00:15<00:19,  1.85it/s, training_loss=0.006]
# Epoch 3:  44%|██████████████████████▊                             | 28/64 [00:15<00:19,  1.83it/s, training_loss=0.006]
# Epoch 3:  44%|██████████████████████▊                             | 28/64 [00:15<00:19,  1.83it/s, training_loss=0.005]
# Epoch 3:  45%|███████████████████████▌                            | 29/64 [00:15<00:19,  1.82it/s, training_loss=0.005]
# Epoch 3:  45%|███████████████████████▌                            | 29/64 [00:16<00:19,  1.82it/s, training_loss=0.006]
# Epoch 3:  47%|████████████████████████▍                           | 30/64 [00:16<00:18,  1.86it/s, training_loss=0.006]
# Epoch 3:  47%|████████████████████████▍                           | 30/64 [00:16<00:18,  1.86it/s, training_loss=0.006]
# Epoch 3:  48%|█████████████████████████▏                          | 31/64 [00:16<00:17,  1.85it/s, training_loss=0.006]
# Epoch 3:  48%|█████████████████████████▏                          | 31/64 [00:17<00:17,  1.85it/s, training_loss=0.005]
# Epoch 3:  50%|██████████████████████████                          | 32/64 [00:17<00:17,  1.85it/s, training_loss=0.005]
# Epoch 3:  50%|██████████████████████████                          | 32/64 [00:17<00:17,  1.85it/s, training_loss=0.022]
# Epoch 3:  52%|██████████████████████████▊                         | 33/64 [00:17<00:16,  1.87it/s, training_loss=0.022]
# Epoch 3:  52%|██████████████████████████▊                         | 33/64 [00:18<00:16,  1.87it/s, training_loss=0.005]
# Epoch 3:  53%|███████████████████████████▋                        | 34/64 [00:18<00:16,  1.87it/s, training_loss=0.005]
# Epoch 3:  53%|███████████████████████████▋                        | 34/64 [00:18<00:16,  1.87it/s, training_loss=0.005]
# Epoch 3:  55%|████████████████████████████▍                       | 35/64 [00:18<00:15,  1.86it/s, training_loss=0.005]
# Epoch 3:  55%|████████████████████████████▍                       | 35/64 [00:19<00:15,  1.86it/s, training_loss=0.004]
# Epoch 3:  56%|█████████████████████████████▎                      | 36/64 [00:19<00:15,  1.84it/s, training_loss=0.004]
# Epoch 3:  56%|█████████████████████████████▎                      | 36/64 [00:19<00:15,  1.84it/s, training_loss=0.004]
# Epoch 3:  58%|██████████████████████████████                      | 37/64 [00:19<00:14,  1.86it/s, training_loss=0.004]
# Epoch 3:  58%|██████████████████████████████                      | 37/64 [00:20<00:14,  1.86it/s, training_loss=0.005]
# Epoch 3:  59%|██████████████████████████████▉                     | 38/64 [00:20<00:14,  1.85it/s, training_loss=0.005]
# Epoch 3:  59%|██████████████████████████████▉                     | 38/64 [00:20<00:14,  1.85it/s, training_loss=0.005]
# Epoch 3:  61%|███████████████████████████████▋                    | 39/64 [00:21<00:13,  1.83it/s, training_loss=0.005]
# Epoch 3:  61%|███████████████████████████████▋                    | 39/64 [00:21<00:13,  1.83it/s, training_loss=0.004]
# Epoch 3:  62%|████████████████████████████████▌                   | 40/64 [00:21<00:13,  1.83it/s, training_loss=0.004]
# Epoch 3:  62%|████████████████████████████████▌                   | 40/64 [00:22<00:13,  1.83it/s, training_loss=0.005]
# Epoch 3:  64%|█████████████████████████████████▎                  | 41/64 [00:22<00:12,  1.81it/s, training_loss=0.005]
# Epoch 3:  64%|█████████████████████████████████▎                  | 41/64 [00:22<00:12,  1.81it/s, training_loss=0.004]
# Epoch 3:  66%|██████████████████████████████████▏                 | 42/64 [00:22<00:12,  1.76it/s, training_loss=0.004]
# Epoch 3:  66%|██████████████████████████████████▏                 | 42/64 [00:23<00:12,  1.76it/s, training_loss=0.004]
# Epoch 3:  67%|██████████████████████████████████▉                 | 43/64 [00:23<00:12,  1.75it/s, training_loss=0.004]
# Epoch 3:  67%|██████████████████████████████████▉                 | 43/64 [00:23<00:12,  1.75it/s, training_loss=0.004]
# Epoch 3:  69%|███████████████████████████████████▊                | 44/64 [00:23<00:11,  1.78it/s, training_loss=0.004]
# Epoch 3:  69%|███████████████████████████████████▊                | 44/64 [00:24<00:11,  1.78it/s, training_loss=0.005]
# Epoch 3:  70%|████████████████████████████████████▌               | 45/64 [00:24<00:10,  1.78it/s, training_loss=0.005]
# Epoch 3:  70%|████████████████████████████████████▌               | 45/64 [00:24<00:10,  1.78it/s, training_loss=0.004]
# Epoch 3:  72%|█████████████████████████████████████▍              | 46/64 [00:24<00:10,  1.78it/s, training_loss=0.004]
# Epoch 3:  72%|█████████████████████████████████████▍              | 46/64 [00:25<00:10,  1.78it/s, training_loss=0.004]
# Epoch 3:  73%|██████████████████████████████████████▏             | 47/64 [00:25<00:09,  1.79it/s, training_loss=0.004]
# Epoch 3:  73%|██████████████████████████████████████▏             | 47/64 [00:26<00:09,  1.79it/s, training_loss=0.004]
# Epoch 3:  75%|███████████████████████████████████████             | 48/64 [00:26<00:08,  1.80it/s, training_loss=0.004]
# Epoch 3:  75%|███████████████████████████████████████             | 48/64 [00:26<00:08,  1.80it/s, training_loss=0.004]
# Epoch 3:  77%|███████████████████████████████████████▊            | 49/64 [00:26<00:08,  1.74it/s, training_loss=0.004]
# Epoch 3:  77%|███████████████████████████████████████▊            | 49/64 [00:27<00:08,  1.74it/s, training_loss=0.005]
# Epoch 3:  78%|████████████████████████████████████████▋           | 50/64 [00:27<00:08,  1.74it/s, training_loss=0.005]
# Epoch 3:  78%|████████████████████████████████████████▋           | 50/64 [00:27<00:08,  1.74it/s, training_loss=0.005]
# Epoch 3:  80%|█████████████████████████████████████████▍          | 51/64 [00:27<00:07,  1.77it/s, training_loss=0.005]
# Epoch 3:  80%|█████████████████████████████████████████▍          | 51/64 [00:28<00:07,  1.77it/s, training_loss=0.005]
# Epoch 3:  81%|██████████████████████████████████████████▎         | 52/64 [00:28<00:06,  1.77it/s, training_loss=0.005]
# Epoch 3:  81%|██████████████████████████████████████████▎         | 52/64 [00:28<00:06,  1.77it/s, training_loss=0.004]
# Epoch 3:  83%|███████████████████████████████████████████         | 53/64 [00:28<00:06,  1.78it/s, training_loss=0.004]
# Epoch 3:  83%|███████████████████████████████████████████         | 53/64 [00:29<00:06,  1.78it/s, training_loss=0.006]
# Epoch 3:  84%|███████████████████████████████████████████▉        | 54/64 [00:29<00:05,  1.78it/s, training_loss=0.006]
# Epoch 3:  84%|███████████████████████████████████████████▉        | 54/64 [00:30<00:05,  1.78it/s, training_loss=0.004]
# Epoch 3:  86%|████████████████████████████████████████████▋       | 55/64 [00:30<00:04,  1.81it/s, training_loss=0.004]
# Epoch 3:  86%|████████████████████████████████████████████▋       | 55/64 [00:30<00:04,  1.81it/s, training_loss=0.004]
# Epoch 3:  88%|█████████████████████████████████████████████▌      | 56/64 [00:30<00:04,  1.80it/s, training_loss=0.004]
# Epoch 3:  88%|█████████████████████████████████████████████▌      | 56/64 [00:31<00:04,  1.80it/s, training_loss=0.004]
# Epoch 3:  89%|██████████████████████████████████████████████▎     | 57/64 [00:31<00:03,  1.80it/s, training_loss=0.004]
# Epoch 3:  89%|██████████████████████████████████████████████▎     | 57/64 [00:31<00:03,  1.80it/s, training_loss=0.004]
# Epoch 3:  91%|███████████████████████████████████████████████▏    | 58/64 [00:31<00:03,  1.81it/s, training_loss=0.004]
# Epoch 3:  91%|███████████████████████████████████████████████▏    | 58/64 [00:32<00:03,  1.81it/s, training_loss=0.004]
# Epoch 3:  92%|███████████████████████████████████████████████▉    | 59/64 [00:32<00:02,  1.83it/s, training_loss=0.004]
# Epoch 3:  92%|███████████████████████████████████████████████▉    | 59/64 [00:32<00:02,  1.83it/s, training_loss=0.004]
# Epoch 3:  94%|████████████████████████████████████████████████▊   | 60/64 [00:32<00:02,  1.83it/s, training_loss=0.004]
# Epoch 3:  94%|████████████████████████████████████████████████▊   | 60/64 [00:33<00:02,  1.83it/s, training_loss=0.004]
# Epoch 3:  95%|█████████████████████████████████████████████████▌  | 61/64 [00:33<00:01,  1.83it/s, training_loss=0.004]
# Epoch 3:  95%|█████████████████████████████████████████████████▌  | 61/64 [00:33<00:01,  1.83it/s, training_loss=0.003]
# Epoch 3:  97%|██████████████████████████████████████████████████▍ | 62/64 [00:33<00:01,  1.85it/s, training_loss=0.003]
# Epoch 3:  97%|██████████████████████████████████████████████████▍ | 62/64 [00:34<00:01,  1.85it/s, training_loss=0.003]
# Epoch 3:  98%|███████████████████████████████████████████████████▏| 63/64 [00:34<00:00,  1.85it/s, training_loss=0.003]
# Epoch 3:  98%|███████████████████████████████████████████████████▏| 63/64 [00:34<00:00,  1.85it/s, training_loss=0.003]
# Epoch 3: 100%|████████████████████████████████████████████████████| 64/64 [00:34<00:00,  1.95it/s, training_loss=0.003]
#  20%|████████████████▌                                                                  | 2/10 [01:50<04:57, 37.24s/it]
# Epoch 3
# Training loss: 0.02402340307889972
#  30%|████████████████████████▉                                                          | 3/10 [01:52<04:22, 37.46s/it]
# Epoch 4:   0%|                                                                                  | 0/64 [00:00<?, ?it/s]
# Validation loss: 0.00871077529154718
# F1 Score (Weighted): 1.0
# Epoch 4:   0%|                                                             | 0/64 [00:00<?, ?it/s, training_loss=0.003]
# Epoch 4:   2%|▊                                                    | 1/64 [00:00<00:32,  1.95it/s, training_loss=0.003]
# ...
# Epoch 10:   0%|                                                                                 | 0/64 [00:00<?, ?it/s]
# Validation loss: 0.0026867854758165777
# F1 Score (Weighted): 1.0
# Epoch 10:   0%|                                                            | 0/64 [00:00<?, ?it/s, training_loss=0.001]
# Epoch 10:   2%|▊                                                   | 1/64 [00:00<00:33,  1.88it/s, training_loss=0.001]
# Epoch 10:   2%|▊                                                   | 1/64 [00:01<00:33,  1.88it/s, training_loss=0.001]
# Epoch 10:   3%|█▋                                                  | 2/64 [00:01<00:33,  1.86it/s, training_loss=0.001]
# Epoch 10:   3%|█▋                                                  | 2/64 [00:01<00:33,  1.86it/s, training_loss=0.001]
# Epoch 10:   5%|██▍                                                 | 3/64 [00:01<00:32,  1.87it/s, training_loss=0.001]
# Epoch 10:   5%|██▍                                                 | 3/64 [00:02<00:32,  1.87it/s, training_loss=0.001]
# Epoch 10:   6%|███▎                                                | 4/64 [00:02<00:31,  1.89it/s, training_loss=0.001]
# Epoch 10:   6%|███▎                                                | 4/64 [00:02<00:31,  1.89it/s, training_loss=0.001]
# Epoch 10:   8%|████                                                | 5/64 [00:02<00:31,  1.86it/s, training_loss=0.001]
# Epoch 10:   8%|████                                                | 5/64 [00:03<00:31,  1.86it/s, training_loss=0.001]
# Epoch 10:   9%|████▉                                               | 6/64 [00:03<00:31,  1.86it/s, training_loss=0.001]
# Epoch 10:   9%|████▉                                               | 6/64 [00:03<00:31,  1.86it/s, training_loss=0.001]
# Epoch 10:  11%|█████▋                                              | 7/64 [00:03<00:30,  1.85it/s, training_loss=0.001]
# Epoch 10:  11%|█████▋                                              | 7/64 [00:04<00:30,  1.85it/s, training_loss=0.001]
# Epoch 10:  12%|██████▌                                             | 8/64 [00:04<00:30,  1.84it/s, training_loss=0.001]
# Epoch 10:  12%|██████▌                                             | 8/64 [00:04<00:30,  1.84it/s, training_loss=0.001]
# Epoch 10:  14%|███████▎                                            | 9/64 [00:04<00:30,  1.83it/s, training_loss=0.001]
# Epoch 10:  14%|███████▎                                            | 9/64 [00:05<00:30,  1.83it/s, training_loss=0.001]
# Epoch 10:  16%|███████▉                                           | 10/64 [00:05<00:29,  1.84it/s, training_loss=0.001]
# Epoch 10:  16%|███████▉                                           | 10/64 [00:05<00:29,  1.84it/s, training_loss=0.001]
# Epoch 10:  17%|████████▊                                          | 11/64 [00:05<00:28,  1.85it/s, training_loss=0.001]
# Epoch 10:  17%|████████▊                                          | 11/64 [00:06<00:28,  1.85it/s, training_loss=0.001]
# Epoch 10:  19%|█████████▌                                         | 12/64 [00:06<00:27,  1.87it/s, training_loss=0.001]
# Epoch 10:  19%|█████████▌                                         | 12/64 [00:07<00:27,  1.87it/s, training_loss=0.001]
# Epoch 10:  20%|██████████▎                                        | 13/64 [00:07<00:27,  1.85it/s, training_loss=0.001]
# Epoch 10:  20%|██████████▎                                        | 13/64 [00:07<00:27,  1.85it/s, training_loss=0.001]
# Epoch 10:  22%|███████████▏                                       | 14/64 [00:07<00:27,  1.84it/s, training_loss=0.001]
# Epoch 10:  22%|███████████▏                                       | 14/64 [00:08<00:27,  1.84it/s, training_loss=0.001]
# Epoch 10:  23%|███████████▉                                       | 15/64 [00:08<00:26,  1.87it/s, training_loss=0.001]
# Epoch 10:  23%|███████████▉                                       | 15/64 [00:08<00:26,  1.87it/s, training_loss=0.001]
# Epoch 10:  25%|████████████▊                                      | 16/64 [00:08<00:25,  1.85it/s, training_loss=0.001]
# Epoch 10:  25%|████████████▊                                      | 16/64 [00:09<00:25,  1.85it/s, training_loss=0.001]
# Epoch 10:  27%|█████████████▌                                     | 17/64 [00:09<00:26,  1.79it/s, training_loss=0.001]
# Epoch 10:  27%|█████████████▌                                     | 17/64 [00:09<00:26,  1.79it/s, training_loss=0.001]
# Epoch 10:  28%|██████████████▎                                    | 18/64 [00:09<00:25,  1.81it/s, training_loss=0.001]
# Epoch 10:  28%|██████████████▎                                    | 18/64 [00:10<00:25,  1.81it/s, training_loss=0.001]
# Epoch 10:  30%|███████████████▏                                   | 19/64 [00:10<00:24,  1.82it/s, training_loss=0.001]
# Epoch 10:  30%|███████████████▏                                   | 19/64 [00:10<00:24,  1.82it/s, training_loss=0.001]
# Epoch 10:  31%|███████████████▉                                   | 20/64 [00:10<00:24,  1.83it/s, training_loss=0.001]
# Epoch 10:  31%|███████████████▉                                   | 20/64 [00:11<00:24,  1.83it/s, training_loss=0.001]
# Epoch 10:  33%|████████████████▋                                  | 21/64 [00:11<00:23,  1.82it/s, training_loss=0.001]
# Epoch 10:  33%|████████████████▋                                  | 21/64 [00:11<00:23,  1.82it/s, training_loss=0.001]
# Epoch 10:  34%|█████████████████▌                                 | 22/64 [00:11<00:23,  1.79it/s, training_loss=0.001]
# Epoch 10:  34%|█████████████████▌                                 | 22/64 [00:12<00:23,  1.79it/s, training_loss=0.001]
# Epoch 10:  36%|██████████████████▎                                | 23/64 [00:12<00:22,  1.84it/s, training_loss=0.001]
# Epoch 10:  36%|██████████████████▎                                | 23/64 [00:12<00:22,  1.84it/s, training_loss=0.001]
# Epoch 10:  38%|███████████████████▏                               | 24/64 [00:12<00:21,  1.88it/s, training_loss=0.001]
# Epoch 10:  38%|███████████████████▏                               | 24/64 [00:13<00:21,  1.88it/s, training_loss=0.001]
# Epoch 10:  39%|███████████████████▉                               | 25/64 [00:13<00:20,  1.89it/s, training_loss=0.001]
# Epoch 10:  39%|███████████████████▉                               | 25/64 [00:14<00:20,  1.89it/s, training_loss=0.001]
# Epoch 10:  41%|████████████████████▋                              | 26/64 [00:14<00:20,  1.87it/s, training_loss=0.001]
# Epoch 10:  41%|████████████████████▋                              | 26/64 [00:14<00:20,  1.87it/s, training_loss=0.001]
# Epoch 10:  42%|█████████████████████▌                             | 27/64 [00:14<00:19,  1.89it/s, training_loss=0.001]
# Epoch 10:  42%|█████████████████████▌                             | 27/64 [00:15<00:19,  1.89it/s, training_loss=0.001]
# Epoch 10:  44%|██████████████████████▎                            | 28/64 [00:15<00:18,  1.91it/s, training_loss=0.001]
# Epoch 10:  44%|██████████████████████▎                            | 28/64 [00:15<00:18,  1.91it/s, training_loss=0.001]
# Epoch 10:  45%|███████████████████████                            | 29/64 [00:15<00:18,  1.85it/s, training_loss=0.001]
# Epoch 10:  45%|███████████████████████                            | 29/64 [00:16<00:18,  1.85it/s, training_loss=0.001]
# Epoch 10:  47%|███████████████████████▉                           | 30/64 [00:16<00:18,  1.86it/s, training_loss=0.001]
# Epoch 10:  47%|███████████████████████▉                           | 30/64 [00:16<00:18,  1.86it/s, training_loss=0.001]
# Epoch 10:  48%|████████████████████████▋                          | 31/64 [00:16<00:17,  1.89it/s, training_loss=0.001]
# Epoch 10:  48%|████████████████████████▋                          | 31/64 [00:17<00:17,  1.89it/s, training_loss=0.001]
# Epoch 10:  50%|█████████████████████████▌                         | 32/64 [00:17<00:17,  1.88it/s, training_loss=0.001]
# Epoch 10:  50%|█████████████████████████▌                         | 32/64 [00:17<00:17,  1.88it/s, training_loss=0.001]
# Epoch 10:  52%|██████████████████████████▎                        | 33/64 [00:17<00:16,  1.88it/s, training_loss=0.001]
# Epoch 10:  52%|██████████████████████████▎                        | 33/64 [00:18<00:16,  1.88it/s, training_loss=0.001]
# Epoch 10:  53%|███████████████████████████                        | 34/64 [00:18<00:15,  1.90it/s, training_loss=0.001]
# Epoch 10:  53%|███████████████████████████                        | 34/64 [00:18<00:15,  1.90it/s, training_loss=0.001]
# Epoch 10:  55%|███████████████████████████▉                       | 35/64 [00:18<00:15,  1.92it/s, training_loss=0.001]
# Epoch 10:  55%|███████████████████████████▉                       | 35/64 [00:19<00:15,  1.92it/s, training_loss=0.001]
# Epoch 10:  56%|████████████████████████████▋                      | 36/64 [00:19<00:14,  1.91it/s, training_loss=0.001]
# Epoch 10:  56%|████████████████████████████▋                      | 36/64 [00:19<00:14,  1.91it/s, training_loss=0.001]
# Epoch 10:  58%|█████████████████████████████▍                     | 37/64 [00:19<00:13,  1.94it/s, training_loss=0.001]
# Epoch 10:  58%|█████████████████████████████▍                     | 37/64 [00:20<00:13,  1.94it/s, training_loss=0.001]
# Epoch 10:  59%|██████████████████████████████▎                    | 38/64 [00:20<00:13,  1.96it/s, training_loss=0.001]
# Epoch 10:  59%|██████████████████████████████▎                    | 38/64 [00:20<00:13,  1.96it/s, training_loss=0.001]
# Epoch 10:  61%|███████████████████████████████                    | 39/64 [00:20<00:12,  1.97it/s, training_loss=0.001]
# Epoch 10:  61%|███████████████████████████████                    | 39/64 [00:21<00:12,  1.97it/s, training_loss=0.001]
# Epoch 10:  62%|███████████████████████████████▉                   | 40/64 [00:21<00:12,  1.97it/s, training_loss=0.001]
# Epoch 10:  62%|███████████████████████████████▉                   | 40/64 [00:21<00:12,  1.97it/s, training_loss=0.001]
# Epoch 10:  64%|████████████████████████████████▋                  | 41/64 [00:21<00:11,  1.97it/s, training_loss=0.001]
# Epoch 10:  64%|████████████████████████████████▋                  | 41/64 [00:22<00:11,  1.97it/s, training_loss=0.001]
# Epoch 10:  66%|█████████████████████████████████▍                 | 42/64 [00:22<00:11,  1.88it/s, training_loss=0.001]
# Epoch 10:  66%|█████████████████████████████████▍                 | 42/64 [00:23<00:11,  1.88it/s, training_loss=0.001]
# Epoch 10:  67%|██████████████████████████████████▎                | 43/64 [00:23<00:11,  1.83it/s, training_loss=0.001]
# Epoch 10:  67%|██████████████████████████████████▎                | 43/64 [00:23<00:11,  1.83it/s, training_loss=0.001]
# Epoch 10:  69%|███████████████████████████████████                | 44/64 [00:23<00:10,  1.83it/s, training_loss=0.001]
# Epoch 10:  69%|███████████████████████████████████                | 44/64 [00:24<00:10,  1.83it/s, training_loss=0.001]
# Epoch 10:  70%|███████████████████████████████████▊               | 45/64 [00:24<00:10,  1.82it/s, training_loss=0.001]
# Epoch 10:  70%|███████████████████████████████████▊               | 45/64 [00:24<00:10,  1.82it/s, training_loss=0.001]
# Epoch 10:  72%|████████████████████████████████████▋              | 46/64 [00:24<00:10,  1.71it/s, training_loss=0.001]
# Epoch 10:  72%|████████████████████████████████████▋              | 46/64 [00:25<00:10,  1.71it/s, training_loss=0.001]
# Epoch 10:  73%|█████████████████████████████████████▍             | 47/64 [00:25<00:09,  1.75it/s, training_loss=0.001]
# Epoch 10:  73%|█████████████████████████████████████▍             | 47/64 [00:25<00:09,  1.75it/s, training_loss=0.001]
# Epoch 10:  75%|██████████████████████████████████████▎            | 48/64 [00:25<00:08,  1.80it/s, training_loss=0.001]
# Epoch 10:  75%|██████████████████████████████████████▎            | 48/64 [00:26<00:08,  1.80it/s, training_loss=0.001]
# Epoch 10:  77%|███████████████████████████████████████            | 49/64 [00:26<00:08,  1.82it/s, training_loss=0.001]
# Epoch 10:  77%|███████████████████████████████████████            | 49/64 [00:26<00:08,  1.82it/s, training_loss=0.001]
# Epoch 10:  78%|███████████████████████████████████████▊           | 50/64 [00:26<00:07,  1.82it/s, training_loss=0.001]
# Epoch 10:  78%|███████████████████████████████████████▊           | 50/64 [00:27<00:07,  1.82it/s, training_loss=0.001]
# Epoch 10:  80%|████████████████████████████████████████▋          | 51/64 [00:27<00:07,  1.81it/s, training_loss=0.001]
# Epoch 10:  80%|████████████████████████████████████████▋          | 51/64 [00:28<00:07,  1.81it/s, training_loss=0.002]
# Epoch 10:  81%|█████████████████████████████████████████▍         | 52/64 [00:28<00:07,  1.67it/s, training_loss=0.002]
# Epoch 10:  81%|█████████████████████████████████████████▍         | 52/64 [00:28<00:07,  1.67it/s, training_loss=0.001]
# Epoch 10:  83%|██████████████████████████████████████████▏        | 53/64 [00:28<00:06,  1.70it/s, training_loss=0.001]
# Epoch 10:  83%|██████████████████████████████████████████▏        | 53/64 [00:29<00:06,  1.70it/s, training_loss=0.001]
# Epoch 10:  84%|███████████████████████████████████████████        | 54/64 [00:29<00:05,  1.74it/s, training_loss=0.001]
# Epoch 10:  84%|███████████████████████████████████████████        | 54/64 [00:29<00:05,  1.74it/s, training_loss=0.001]
# Epoch 10:  86%|███████████████████████████████████████████▊       | 55/64 [00:29<00:05,  1.78it/s, training_loss=0.001]
# Epoch 10:  86%|███████████████████████████████████████████▊       | 55/64 [00:30<00:05,  1.78it/s, training_loss=0.001]
# Epoch 10:  88%|████████████████████████████████████████████▋      | 56/64 [00:30<00:04,  1.80it/s, training_loss=0.001]
# Epoch 10:  88%|████████████████████████████████████████████▋      | 56/64 [00:30<00:04,  1.80it/s, training_loss=0.001]
# Epoch 10:  89%|█████████████████████████████████████████████▍     | 57/64 [00:30<00:03,  1.81it/s, training_loss=0.001]
# Epoch 10:  89%|█████████████████████████████████████████████▍     | 57/64 [00:31<00:03,  1.81it/s, training_loss=0.001]
# Epoch 10:  91%|██████████████████████████████████████████████▏    | 58/64 [00:31<00:03,  1.81it/s, training_loss=0.001]
# Epoch 10:  91%|██████████████████████████████████████████████▏    | 58/64 [00:31<00:03,  1.81it/s, training_loss=0.001]
# Epoch 10:  92%|███████████████████████████████████████████████    | 59/64 [00:31<00:02,  1.85it/s, training_loss=0.001]
# Epoch 10:  92%|███████████████████████████████████████████████    | 59/64 [00:32<00:02,  1.85it/s, training_loss=0.001]
# Epoch 10:  94%|███████████████████████████████████████████████▊   | 60/64 [00:32<00:02,  1.84it/s, training_loss=0.001]
# Epoch 10:  94%|███████████████████████████████████████████████▊   | 60/64 [00:33<00:02,  1.84it/s, training_loss=0.001]
# Epoch 10:  95%|████████████████████████████████████████████████▌  | 61/64 [00:33<00:01,  1.82it/s, training_loss=0.001]
# Epoch 10:  95%|████████████████████████████████████████████████▌  | 61/64 [00:33<00:01,  1.82it/s, training_loss=0.001]
# Epoch 10:  97%|█████████████████████████████████████████████████▍ | 62/64 [00:33<00:01,  1.83it/s, training_loss=0.001]
# Epoch 10:  97%|█████████████████████████████████████████████████▍ | 62/64 [00:34<00:01,  1.83it/s, training_loss=0.001]
# Epoch 10:  98%|██████████████████████████████████████████████████▏| 63/64 [00:34<00:00,  1.86it/s, training_loss=0.001]
# Epoch 10:  98%|██████████████████████████████████████████████████▏| 63/64 [00:34<00:00,  1.86it/s, training_loss=0.001]
# Epoch 10: 100%|███████████████████████████████████████████████████| 64/64 [00:34<00:00,  1.96it/s, training_loss=0.001]
#  90%|██████████████████████████████████████████████████████████████████████████▋        | 9/10 [06:12<00:37, 37.09s/it]
# Epoch 10
# Training loss: 0.0032667596206010785
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:13<00:00, 37.39s/it]
# Validation loss: 0.0026765443617478013
# F1 Score (Weighted): 1.0

# %%
for i, pair in enumerate(zip(vloss, score)):
    print(i, pair[0], pair[1])
# Out:
# 0 0.15310885570943356 1.0
# 1 0.022375446899483602 1.0
# 2 0.00871077529154718 1.0
# 3 0.004871172791657348 1.0
# 4 0.06245090771699324 0.9777667984189722
# 5 0.0033734951672765114 1.0
# 6 0.002955494448542595 1.0
# 7 0.002763028761061529 1.0
# 8 0.0026867854758165777 1.0
# 9 0.0026765443617478013 1.0

# %%
model.to(device)
model.load_state_dict(torch.load('./bert polarity/BERT_polarity_epoch_10.pt', map_location=torch.device('cpu')))

_, predictions, actual = evaluate(valid_dataloader)
print(acpc(predictions, actual))
labs = {v:k for k,v in labels_dict.items()}
for i in range (len(predictions)):
    print(labs[np.argmax(predictions[i])], val_texts[i])
    print()
# Out:
# Class: POSITIVE
# Accuracy: 1.0
#
# Class: NEGATIVE
# Accuracy: 1.0
#
# None
# NEGATIVE She sucks. Was never qualified. Loser
#
# POSITIVE Rock on brother this says it all.. love it
#
# NEGATIVE Ironic the very media platform that has gone to great lengths to incite devise ness is projecting a victim of their bullshit is being silenced. This is a bad movie
#
# POSITIVE It's very deep and very real!
#
# POSITIVE Absolutely great first move by Trump and the GOP!!
#
# NEGATIVE a href="/profile/HughHewitt/posts" class="at">@HughHewitt</a> You maybe a lot of things but never knew deaf dumb and blind were part of your weaknesses? I am exactly your age and remember the past as u put it. What if 75 million Trumpers stop voting? Clean what up in 4 years? Wonât be anything to clean up! Iâm done voting and have all my life! Done! And done listening to pundits! U are lost!
#
# NEGATIVE Sickening
#
# POSITIVE Good Morning! Have a great day!
#
# POSITIVE Absolutely.
#
# NEGATIVE Clearly not a secure election once again.
#
# POSITIVE May you always be healthy, happy and in love congratulations.
#
# POSITIVE True!! Share to everyone
#
# POSITIVE My friend Tommy here worded this perfectly!!
#
# NEGATIVE I feel a huge "itoldaso" coming in GA... the RNC is worthless.
#
# POSITIVE Thank you Lin and President Trump - all Patriots love you!!!
#
# POSITIVE Thank you!! Keep up the fight!!! Millions of us are with you
#
# NEGATIVE Stupid commie cops of Washington.
#
# NEGATIVE Stop saying burn that building down. Its not going to solve anything. We need to confrunt them, the building is not to blame
#
# NEGATIVE The police (oathbreakers in blue states) has lost the support of the patriots.
#
# POSITIVE Great show, I appreciate your show. I'm sleeper warrior for God. Thank you. Stay strong
#
# NEGATIVE Sadly I am not surprised. Another in your face cheat. Until we see arrests, there will be no trust in our elections or our government.
#
# NEGATIVE Someone needs to shove a boot up her ASS. Dems are called dimwits for a reason. Not the brightest stars in the sky.
#
# POSITIVE good read. happy to hear perspectives on this:
#
# POSITIVE Fantastic!
#
# NEGATIVE Unfortunately, the TRUTH no longer matters!
#
# POSITIVE You are very welcome it is very inspiring.... Allen West is the real deal!!!
#
# NEGATIVE At this point this country is a shit show so how much worse could it get?
#
# NEGATIVE Mitch is the WORST KIND OF TRAITOR BACK STABBER, SNAKE
#
# NEGATIVE what attack? I feel like this joint session is a waste of time. they don't believe there was fraud ..which I just don't understand
#
# NEGATIVE As I suspected. In regards to the Capital Hill occupation, this type of display never works. And this was not in anyoneâs best interest. Any future protests should be done at the state level. There in lies the significant voter fraud and corruption. This is where change needs to be addressed for future elections. This is not the Soviet Union, it is the United States. States run the election show.
#
# NEGATIVE Poor president trump.
#
# POSITIVE Awesome!! Edits!!!
#
# POSITIVE Absolutely true brother!
#
# POSITIVE Love it when the truth emerges.
#
# NEGATIVE No surprise. Idiots
#
# NEGATIVE Nonsense. Man u
#
# NEGATIVE #KabukiShow That's all Pence was... #TraitorTrump rips Pence: 'Didnât have the courage to do what should have been done'
#
# NEGATIVE Pathetic!
#
# POSITIVE That is a tremendous amount!
#
# POSITIVE Thank you Patriot!
#
# NEGATIVE No one wants to hear another word from that guyâs mouth. We already know thereâs no redeeming quality of any utterance from either him or his worthless brother.
#
# POSITIVE Oh I love this.
#
# NEGATIVE We are supposed to believe (based on this tweet and perceived evidence) that Pelosi's office was vandalized and this folder was left...#vaccines#pennsylvania#katebrown#2020election#electoralcollegevote#electoralcollege#portland#nevada#newyork#washingtonstate
#
# POSITIVE He is an awesome Patriot.
#
# POSITIVE Awesome!
#
# NEGATIVE Idiots at #abcnews saying Trump supporters at the #capitol are a violent mob. Disgraceful
#
# NEGATIVE Such a disappointment!
#
# NEGATIVE Sad to say but I believe we are down to one option and its not gonna be fun.
#
# POSITIVE Best happy ending ever..!!
#
# POSITIVE THIS IS SO AMAZING I THINK I AM GOING TO BREAK DOWN AND CRY FROM JOY THAT WE WILL OVERCOME! GOD BLESS THE U.S.A.!
#
# NEGATIVE Itâs like watching a poorly produced âB Movieâ At least get some better ACTORS
#
# NEGATIVE Another disappointment.
#
# NEGATIVE they need to stop the count, so they can get the reinforcement of the pre- printed ballots? So dirty and so corrupt!!
#
# NEGATIVE The Jewish rulers of America are starting their propaganda against #Whites already. It will get worse:
#
# POSITIVE So AWESOME!!
#
# NEGATIVE It is their fault, and this will only get worse.
#
# POSITIVE We are mighty and strong when we unite!
#
# POSITIVE A TRUE WARRIOR!
#
# POSITIVE GOTTA LOVE IT!
#
# NEGATIVE Gawd, how pathetic those men are lying down there with their masks on. Gross.
#
# NEGATIVE "Stupid is as stupid does."
#
# NEGATIVE I really hate to say this, but this is all starting to sound like a lot of b.s.. Two months of hearing empty threats of all this supposed evidence and here we are.... nothing!
#
# POSITIVE Absolutely Brilliant
#
# NEGATIVE Lin Wood isnât reliable.
#
# NEGATIVE Unbelievable....it just gets worse!
#
# POSITIVE This makes me so happy. Doing it right patriots, doing it rightðºð¸ðºð¸ðºð¸ðºð¸
#
# NEGATIVE I beg Vernon Jones to please reconsider joining the Republican party. That will be a big waste of your talent. You really need to check on and investigate maybe starting your own political party. I would be honored to be one of your first members!
#
# POSITIVE PROUD TO BE AN AMERIKKKAN!
#
# POSITIVE Thank you for parlaying this inspiring video
#
# POSITIVE Just beautiful
#
# NEGATIVE UTTERLY DISGRACEFUL
#
# POSITIVE Glorious
#
# POSITIVE Love it!
#
# POSITIVE Powerful
#
# POSITIVE Iâm with you Mr President Iâll never give up hope . You are the BEST PRESIDENT AMERICA HAS EVER HAD!!!
#
# POSITIVE Make her famous!
#
# POSITIVE Perfect!
#
# POSITIVE Good eye!!!
#
# NEGATIVE I'm so tired of the double standard.
#
# POSITIVE Beautiful!
#
# NEGATIVE If true - Just makes it worse.
#
# POSITIVE You are a total patriot and are very smart
#
# NEGATIVE Really bad
#
# POSITIVE This man is amazing... He NEVER turned his back on Trump...
#
# NEGATIVE You are the worst you will never represent með¡ð¡ð¡ð¡
#
# NEGATIVE Looks like we are missing a few heads on this Wanted Poster!
#
# NEGATIVE Terrible ! Shame on them â
#
# NEGATIVE He can paint his face to disguise his identity. Not smart enough to realize tats are tattle tails.
#
# POSITIVE Happy little blue.
#
# POSITIVE Excellent and well said!
